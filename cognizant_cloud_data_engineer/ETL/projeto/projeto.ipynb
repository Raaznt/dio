# %% [markdown]
# <h1>Extração e validação de dados</h1>

# %%
import pandas as pd
import pandera as pa

# %% [markdown]
# Use o parâmetro **date_parser** para indicar a função a ser usada como parser, bem como indicar o formato da data (por meio do parâmetro **format** da funcao **to_datetime**) no arquivo .csv usado.

# %%
df = pd.read_csv("ocorrencia.csv", sep = ';', date_parser = lambda arg : pd.to_datetime(arg, format="%d/%m/%Y"), parse_dates=['ocorrencia_dia'])
df.tail(10)
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 5157              80453               80453                INCIDENTE
# 5158              80454               80454          INCIDENTE GRAVE
# 5159              80455               80455          INCIDENTE GRAVE
# 5160              80451               80451                INCIDENTE
# 5161              80456               80456                INCIDENTE
# 5162              80458               80458                 ACIDENTE
# 5163              80452               80452                 ACIDENTE
# 5164              80457               80457          INCIDENTE GRAVE
# 5165              80460               80460                INCIDENTE
# 5166              80467               80467                INCIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 5157          CAMPINAS            SP                 SBKP     2021-12-29
# 5158         ARAÇATUBA            SP                 SBAU     2021-12-29
# 5159        SANTA RITA            PB                *****     2021-12-29
# 5160            MANAUS            AM                 SBEG     2021-12-30
# 5161         SÃO PAULO            SP                 SBSP     2021-12-30
# 5162             JATAÍ            GO                 ####     2021-12-30
# 5163           MARACAÍ            SP                *****     2021-12-31
# 5164     NOVO HAMBURGO            RS                 SSNH     2021-12-31
# 5165          CURITIBA            PR                 SBBI     2021-12-31
# 5166         PETROLINA            PE                 SBPL     2021-12-31
#
#      ocorrencia_hora  total_recomendacoes
# 5157        09:00:00                    0
# 5158        21:35:00                    0
# 5159        18:50:00                    0
# 5160        14:41:00                    0
# 5161        13:15:00                    0
# 5162        20:30:00                    0
# 5163        09:30:00                    0
# 5164        11:59:00                    0
# 5165        15:12:00                    0
# 5166        20:30:00                    0

# %% [markdown]
# Os **schemas** são usados para validação de dataframes. Quando o código abaixo é executado, por exemplo, o dataframe é exibido se o nome da coluna e o tipo dos dados é correto, caso contrário um erro é exibido.

# %%
schema = pa.DataFrameSchema(
    columns = {
        "codigo":pa.Column(pa.Int, required=False),
        "codigo_ocorrencia":pa.Column(pa.Int),
        "codigo_ocorrencia2":pa.Column(pa.Int),
        "ocorrencia_classificacao":pa.Column(pa.String),
        "ocorrencia_cidade":pa.Column(pa.String),
        "ocorrencia_uf":pa.Column(pa.String, pa.Check.str_length(2, 2)),
        "ocorrencia_aerodromo":pa.Column(pa.String),
        "ocorrencia_dia":pa.Column(pa.DateTime),
        "ocorrencia_hora":pa.Column(pa.String, pa.Check.str_matches(r'^([0-1]?[0-9]|[2][0-3]):([0-5][0-9])(:[0-5][0-9])?$'),nullable=True),
        "total_recomendacoes":pa.Column(pa.Int)
    }
)

# %% [markdown]
# Por padrão as colunas são **required=*True*** indicando que devem aparecer obrigatoriamente no dataframe. Quando houver a possibilidade da coluna não aparecer no dataframe deve-se usar **required=*False*** como ocorre acima com a coluna "código".

# %%
schema.validate(df)
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 52242               52242                INCIDENTE
# 1                 45331               45331                 ACIDENTE
# 2                 45333               45333                 ACIDENTE
# 3                 45401               45401                 ACIDENTE
# 4                 45407               45407                 ACIDENTE
# ...                 ...                 ...                      ...
# 5162              80458               80458                 ACIDENTE
# 5163              80452               80452                 ACIDENTE
# 5164              80457               80457          INCIDENTE GRAVE
# 5165              80460               80460                INCIDENTE
# 5166              80467               80467                INCIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0         PORTO ALEGRE            RS                 SBPA     2012-01-05
# 1            GUARULHOS            SP                 SBGR     2012-01-06
# 2               VIAMÃO            RS                 ****     2012-01-06
# 3        SÃO SEBASTIÃO            SP                 ****     2012-01-06
# 4             SÃO SEPÉ            RS                 ****     2012-01-06
# ...                ...           ...                  ...            ...
# 5162             JATAÍ            GO                 ####     2021-12-30
# 5163           MARACAÍ            SP                *****     2021-12-31
# 5164     NOVO HAMBURGO            RS                 SSNH     2021-12-31
# 5165          CURITIBA            PR                 SBBI     2021-12-31
# 5166         PETROLINA            PE                 SBPL     2021-12-31
#
#      ocorrencia_hora  total_recomendacoes
# 0           20:27:00                    0
# 1           13:44:00                    3
# 2           13:00:00                    0
# 3           17:00:00                    0
# 4           16:30:00                    0
# ...              ...                  ...
# 5162        20:30:00                    0
# 5163        09:30:00                    0
# 5164        11:59:00                    0
# 5165        15:12:00                    0
# 5166        20:30:00                    0
#
# [5167 rows x 9 columns]

# %% [raw]
# df.dtypes
# df.ocorrencia_dia.dt.month

# %% [markdown]
# A instrução abaixo é usada na exibição do tipo de dados por coluna

# %%
df.dtypes
# Out:
# codigo_ocorrencia                    int64
# codigo_ocorrencia2                   int64
# ocorrencia_classificacao            object
# ocorrencia_cidade                   object
# ocorrencia_uf                       object
# ocorrencia_aerodromo                object
# ocorrencia_dia              datetime64[ns]
# ocorrencia_hora                     object
# total_recomendacoes                  int64
# dtype: object

# %% [markdown]
# <h1>Limpeza de dados</h1>

# %%
df = pd.read_csv("ocorrencia.csv", sep = ';', date_parser = lambda arg : pd.to_datetime(arg, format="%d/%m/%Y"), parse_dates=['ocorrencia_dia'])
df.head(5)
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              52242               52242                INCIDENTE
# 1              45331               45331                 ACIDENTE
# 2              45333               45333                 ACIDENTE
# 3              45401               45401                 ACIDENTE
# 4              45407               45407                 ACIDENTE
#
#   ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0      PORTO ALEGRE            RS                 SBPA     2012-01-05
# 1         GUARULHOS            SP                 SBGR     2012-01-06
# 2            VIAMÃO            RS                 ****     2012-01-06
# 3     SÃO SEBASTIÃO            SP                 ****     2012-01-06
# 4          SÃO SEPÉ            RS                 ****     2012-01-06
#
#   ocorrencia_hora  total_recomendacoes
# 0        20:27:00                    0
# 1        13:44:00                    3
# 2        13:00:00                    0
# 3        17:00:00                    0
# 4        16:30:00                    0

# %%
df.loc[1, 'ocorrencia_cidade']
# Out:
# 'GUARULHOS'

# %% [markdown]
# O dataframe pode ser interpretado como matriz e os dados podem ser obtidos fazendo uso de labels. Acima, obtemos o dado na linha 1 e coluna 'ocorrencia_cidade'.

# %% [markdown]
# Podemos obter os dados de uma ou mais linhas da seguinte forma:

# %%
df.loc[[10,40]]
# Out:
#     codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 10              45332               45332                 ACIDENTE
# 40              45415               45415                 ACIDENTE
#
#    ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 10            VIAMÃO            RS                 ****     2012-01-09
# 40    RIO DE JANEIRO            RJ                 ****     2012-01-30
#
#    ocorrencia_hora  total_recomendacoes
# 10        13:30:00                    0
# 40        13:55:00                    0

# %% [markdown]
# Podemos obter os dados de uma ou mais colunas da seguinte forma:

# %%
df.loc[:, ['ocorrencia_cidade','ocorrencia_uf']]
# Out:
#      ocorrencia_cidade ocorrencia_uf
# 0         PORTO ALEGRE            RS
# 1            GUARULHOS            SP
# 2               VIAMÃO            RS
# 3        SÃO SEBASTIÃO            SP
# 4             SÃO SEPÉ            RS
# ...                ...           ...
# 5162             JATAÍ            GO
# 5163           MARACAÍ            SP
# 5164     NOVO HAMBURGO            RS
# 5165          CURITIBA            PR
# 5166         PETROLINA            PE
#
# [5167 rows x 2 columns]

# %% [markdown]
# Uma forma mais simplificada de obter uma ou mais colunas como no caso anterior segue abaixo:

# %%
df[['ocorrencia_cidade','ocorrencia_uf']]
# Out:
#      ocorrencia_cidade ocorrencia_uf
# 0         PORTO ALEGRE            RS
# 1            GUARULHOS            SP
# 2               VIAMÃO            RS
# 3        SÃO SEBASTIÃO            SP
# 4             SÃO SEPÉ            RS
# ...                ...           ...
# 5162             JATAÍ            GO
# 5163           MARACAÍ            SP
# 5164     NOVO HAMBURGO            RS
# 5165          CURITIBA            PR
# 5166         PETROLINA            PE
#
# [5167 rows x 2 columns]

# %% [markdown]
# **Sugestão do professor:** Se todos os valores em uma coluna possuir um valor único por linha essa coluna pode ser usada para indexação das linhas no dataframe.

# %% [markdown]
# Por exemplo, o código abaixo verifica se a coluna codigo_ocorrencia do dataframe é único.

# %%
df.codigo_ocorrencia.is_unique
# Out:
# True

# %% [markdown]
# Se a coluna possuir valores únicos por linha ela pode ser usada para indexação das linhas no dataframe por meio do comando abaixo:

# %%
df.set_index('codigo_ocorrencia')
# Out:
#                    codigo_ocorrencia2 ocorrencia_classificacao  \
# codigo_ocorrencia
# 52242                           52242                INCIDENTE
# 45331                           45331                 ACIDENTE
# 45333                           45333                 ACIDENTE
# 45401                           45401                 ACIDENTE
# 45407                           45407                 ACIDENTE
# ...                               ...                      ...
# 80458                           80458                 ACIDENTE
# 80452                           80452                 ACIDENTE
# 80457                           80457          INCIDENTE GRAVE
# 80460                           80460                INCIDENTE
# 80467                           80467                INCIDENTE
#
#                   ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo  \
# codigo_ocorrencia
# 52242                  PORTO ALEGRE            RS                 SBPA
# 45331                     GUARULHOS            SP                 SBGR
# 45333                        VIAMÃO            RS                 ****
# 45401                 SÃO SEBASTIÃO            SP                 ****
# 45407                      SÃO SEPÉ            RS                 ****
# ...                             ...           ...                  ...
# 80458                         JATAÍ            GO                 ####
# 80452                       MARACAÍ            SP                *****
# 80457                 NOVO HAMBURGO            RS                 SSNH
# 80460                      CURITIBA            PR                 SBBI
# 80467                     PETROLINA            PE                 SBPL
#
#                   ocorrencia_dia ocorrencia_hora  total_recomendacoes
# codigo_ocorrencia
# 52242                 2012-01-05        20:27:00                    0
# 45331                 2012-01-06        13:44:00                    3
# 45333                 2012-01-06        13:00:00                    0
# 45401                 2012-01-06        17:00:00                    0
# 45407                 2012-01-06        16:30:00                    0
# ...                          ...             ...                  ...
# 80458                 2021-12-30        20:30:00                    0
# 80452                 2021-12-31        09:30:00                    0
# 80457                 2021-12-31        11:59:00                    0
# 80460                 2021-12-31        15:12:00                    0
# 80467                 2021-12-31        20:30:00                    0
#
# [5167 rows x 8 columns]

# %% [markdown]
# Observe que a coluna 'codigo_ocorrencia' aparece em negrito, indicando que seus valores são índice das linhas. Contudo, o código acima não atualiza os índices do dataframe. Para atualizá-lo use o código abaixo:

# %%
df.set_index('codigo_ocorrencia', inplace=True)

# %%
df.head(5)
# Out:
#                    codigo_ocorrencia2 ocorrencia_classificacao  \
# codigo_ocorrencia
# 52242                           52242                INCIDENTE
# 45331                           45331                 ACIDENTE
# 45333                           45333                 ACIDENTE
# 45401                           45401                 ACIDENTE
# 45407                           45407                 ACIDENTE
#
#                   ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo  \
# codigo_ocorrencia
# 52242                  PORTO ALEGRE            RS                 SBPA
# 45331                     GUARULHOS            SP                 SBGR
# 45333                        VIAMÃO            RS                 ****
# 45401                 SÃO SEBASTIÃO            SP                 ****
# 45407                      SÃO SEPÉ            RS                 ****
#
#                   ocorrencia_dia ocorrencia_hora  total_recomendacoes
# codigo_ocorrencia
# 52242                 2012-01-05        20:27:00                    0
# 45331                 2012-01-06        13:44:00                    3
# 45333                 2012-01-06        13:00:00                    0
# 45401                 2012-01-06        17:00:00                    0
# 45407                 2012-01-06        16:30:00                    0

# %% [markdown]
# Uma vez alterado, o índice pode ser resetado para o utilizado anteriormente por meio do comando abaixo:

# %%
df.reset_index(drop=True, inplace=True)

# %%
df.head(5)
# Out:
#    codigo_ocorrencia2 ocorrencia_classificacao ocorrencia_cidade  \
# 0               52242                INCIDENTE      PORTO ALEGRE
# 1               45331                 ACIDENTE         GUARULHOS
# 2               45333                 ACIDENTE            VIAMÃO
# 3               45401                 ACIDENTE     SÃO SEBASTIÃO
# 4               45407                 ACIDENTE          SÃO SEPÉ
#
#   ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  \
# 0            RS                 SBPA     2012-01-05        20:27:00
# 1            SP                 SBGR     2012-01-06        13:44:00
# 2            RS                 ****     2012-01-06        13:00:00
# 3            SP                 ****     2012-01-06        17:00:00
# 4            RS                 ****     2012-01-06        16:30:00
#
#    total_recomendacoes
# 0                    0
# 1                    3
# 2                    0
# 3                    0
# 4                    0

# %% [markdown]
# Valores podem ser alterados em uma coluna. Por exemplo, o código a seguir altera a coluna ocorrencia_classificacao para grave quando o valor da coluna ocorrencia_uf for SP

# %%
df.loc[df.ocorrencia_uf == 'SP', ['ocorrencia_classificacao']] = 'GRAVE'

# %%
df
# Out:
#       codigo_ocorrencia2 ocorrencia_classificacao ocorrencia_cidade  \
# 0                  52242                INCIDENTE      PORTO ALEGRE
# 1                  45331                    GRAVE         GUARULHOS
# 2                  45333                 ACIDENTE            VIAMÃO
# 3                  45401                    GRAVE     SÃO SEBASTIÃO
# 4                  45407                 ACIDENTE          SÃO SEPÉ
# ...                  ...                      ...               ...
# 5162               80458                 ACIDENTE             JATAÍ
# 5163               80452                    GRAVE           MARACAÍ
# 5164               80457          INCIDENTE GRAVE     NOVO HAMBURGO
# 5165               80460                INCIDENTE          CURITIBA
# 5166               80467                INCIDENTE         PETROLINA
#
#      ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  \
# 0               RS                 SBPA     2012-01-05        20:27:00
# 1               SP                 SBGR     2012-01-06        13:44:00
# 2               RS                 ****     2012-01-06        13:00:00
# 3               SP                 ****     2012-01-06        17:00:00
# 4               RS                 ****     2012-01-06        16:30:00
# ...            ...                  ...            ...             ...
# 5162            GO                 ####     2021-12-30        20:30:00
# 5163            SP                *****     2021-12-31        09:30:00
# 5164            RS                 SSNH     2021-12-31        11:59:00
# 5165            PR                 SBBI     2021-12-31        15:12:00
# 5166            PE                 SBPL     2021-12-31        20:30:00
#
#       total_recomendacoes
# 0                       0
# 1                       3
# 2                       0
# 3                       0
# 4                       0
# ...                   ...
# 5162                    0
# 5163                    0
# 5164                    0
# 5165                    0
# 5166                    0
#
# [5167 rows x 8 columns]

# %%
df.loc[df.ocorrencia_uf=='SP']
# Out:
#       codigo_ocorrencia2 ocorrencia_classificacao  ocorrencia_cidade  \
# 1                  45331                    GRAVE          GUARULHOS
# 3                  45401                    GRAVE      SÃO SEBASTIÃO
# 5                  52243                    GRAVE            UBATUBA
# 6                  50713                    GRAVE           CAMPINAS
# 13                 45408                    GRAVE           ELDORADO
# ...                  ...                      ...                ...
# 5148               80441                    GRAVE  BRAGANÇA PAULISTA
# 5157               80453                    GRAVE           CAMPINAS
# 5158               80454                    GRAVE          ARAÇATUBA
# 5161               80456                    GRAVE          SÃO PAULO
# 5163               80452                    GRAVE            MARACAÍ
#
#      ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  \
# 1               SP                 SBGR     2012-01-06        13:44:00
# 3               SP                 ****     2012-01-06        17:00:00
# 5               SP                 ****     2012-01-06        14:30:00
# 6               SP                 SDAI     2012-01-07        18:15:00
# 13              SP                 ****     2012-01-11        13:45:00
# ...            ...                  ...            ...             ...
# 5148            SP                 SDVH     2021-12-20        18:15:00
# 5157            SP                 SBKP     2021-12-29        09:00:00
# 5158            SP                 SBAU     2021-12-29        21:35:00
# 5161            SP                 SBSP     2021-12-30        13:15:00
# 5163            SP                *****     2021-12-31        09:30:00
#
#       total_recomendacoes
# 1                       3
# 3                       0
# 5                       0
# 6                       0
# 13                      1
# ...                   ...
# 5148                    0
# 5157                    0
# 5158                    0
# 5161                    0
# 5163                    0
#
# [1261 rows x 8 columns]

# %% [markdown]
# Após as alterações podemos atualizar nosso dataframe com os dados do arquivo original com:

# %%
df = pd.read_csv("ocorrencia.csv", sep = ';', date_parser = lambda arg : pd.to_datetime(arg, format="%d/%m/%Y"), parse_dates=['ocorrencia_dia'])
df.tail(10)
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 5157              80453               80453                INCIDENTE
# 5158              80454               80454          INCIDENTE GRAVE
# 5159              80455               80455          INCIDENTE GRAVE
# 5160              80451               80451                INCIDENTE
# 5161              80456               80456                INCIDENTE
# 5162              80458               80458                 ACIDENTE
# 5163              80452               80452                 ACIDENTE
# 5164              80457               80457          INCIDENTE GRAVE
# 5165              80460               80460                INCIDENTE
# 5166              80467               80467                INCIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 5157          CAMPINAS            SP                 SBKP     2021-12-29
# 5158         ARAÇATUBA            SP                 SBAU     2021-12-29
# 5159        SANTA RITA            PB                *****     2021-12-29
# 5160            MANAUS            AM                 SBEG     2021-12-30
# 5161         SÃO PAULO            SP                 SBSP     2021-12-30
# 5162             JATAÍ            GO                 ####     2021-12-30
# 5163           MARACAÍ            SP                *****     2021-12-31
# 5164     NOVO HAMBURGO            RS                 SSNH     2021-12-31
# 5165          CURITIBA            PR                 SBBI     2021-12-31
# 5166         PETROLINA            PE                 SBPL     2021-12-31
#
#      ocorrencia_hora  total_recomendacoes
# 5157        09:00:00                    0
# 5158        21:35:00                    0
# 5159        18:50:00                    0
# 5160        14:41:00                    0
# 5161        13:15:00                    0
# 5162        20:30:00                    0
# 5163        09:30:00                    0
# 5164        11:59:00                    0
# 5165        15:12:00                    0
# 5166        20:30:00                    0

# %% [markdown]
# Para a limpeza de dados buscaremos nas colunas informadas pelos seguintes valores:
#
# Para a coluna ocorrencia_uf:
# <ul>
#     <li>'**'</li>
# </ul>
# Para a coluna ocorrencia_aerodromo
# <ul>
#     <li>'###!'</li>
#     <li>'####'</li>
#     <li>'****'</li>
#     <li>'*****'</li>
# </ul>
# Para a coluna ocorrencia_hora
# <ul>
#     <li>'NULL'</li>
# </ul>

# %%
df.head(5)
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              52242               52242                INCIDENTE
# 1              45331               45331                 ACIDENTE
# 2              45333               45333                 ACIDENTE
# 3              45401               45401                 ACIDENTE
# 4              45407               45407                 ACIDENTE
#
#   ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0      PORTO ALEGRE            RS                 SBPA     2012-01-05
# 1         GUARULHOS            SP                 SBGR     2012-01-06
# 2            VIAMÃO            RS                 ****     2012-01-06
# 3     SÃO SEBASTIÃO            SP                 ****     2012-01-06
# 4          SÃO SEPÉ            RS                 ****     2012-01-06
#
#   ocorrencia_hora  total_recomendacoes
# 0        20:27:00                    0
# 1        13:44:00                    3
# 2        13:00:00                    0
# 3        17:00:00                    0
# 4        16:30:00                    0

# %% [markdown]
# Abaixo substituiremos todos os valores da coluna informada como não disponível por NA (*not available*).

# %%
df.loc[df.ocorrencia_aerodromo=='****', ['ocorrencia_aerodromo']] = pd.NA

# %%
df.head()
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              52242               52242                INCIDENTE
# 1              45331               45331                 ACIDENTE
# 2              45333               45333                 ACIDENTE
# 3              45401               45401                 ACIDENTE
# 4              45407               45407                 ACIDENTE
#
#   ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0      PORTO ALEGRE            RS                 SBPA     2012-01-05
# 1         GUARULHOS            SP                 SBGR     2012-01-06
# 2            VIAMÃO            RS                 <NA>     2012-01-06
# 3     SÃO SEBASTIÃO            SP                 <NA>     2012-01-06
# 4          SÃO SEPÉ            RS                 <NA>     2012-01-06
#
#   ocorrencia_hora  total_recomendacoes
# 0        20:27:00                    0
# 1        13:44:00                    3
# 2        13:00:00                    0
# 3        17:00:00                    0
# 4        16:30:00                    0

# %% [markdown]
# Outra forma de substituir os valores indicados como não disponíveis é por meio da função ***replace()*** que busca por ocorrências de valores informados em uma lista e substitui por ***pd.NA***. O parâmetro ***inplace=True*** permite a alteração de valores no próprio dataframe ao invés de apenas exibi-lo com valores alterados.

# %%
df.replace(['**','###!','####','****','*****','NULL'], pd.NA, inplace=True)

# %% [markdown]
# Tratando os dados indisponíveis como ***pd.NA*** permite o uso de funções úteis disponibilziadas pelo Pandas. O comando abaixo exibe o número de ocorrencias de valores indisponíveis por coluna em um dataframe:

# %%
df.isna().sum()
# Out:
# codigo_ocorrencia              0
# codigo_ocorrencia2             0
# ocorrencia_classificacao       0
# ocorrencia_cidade              0
# ocorrencia_uf                  2
# ocorrencia_aerodromo        1905
# ocorrencia_dia                 0
# ocorrencia_hora                1
# total_recomendacoes            0
# dtype: int64

# %% [markdown]
# A função ***isnull()*** pode também ser usada com o mesmo propósito.

# %%
df.isnull().sum()
# Out:
# codigo_ocorrencia              0
# codigo_ocorrencia2             0
# ocorrencia_classificacao       0
# ocorrencia_cidade              0
# ocorrencia_uf                  2
# ocorrencia_aerodromo        1905
# ocorrencia_dia                 0
# ocorrencia_hora                1
# total_recomendacoes            0
# dtype: int64

# %% [markdown]
# A função ***df.fillna()*** pode ser usada para substituir todos os valores indisponíveis por um valor informado. Para alterar o dataframe, o parâemtro deve ser usado: ***inplace=True***.

# %%
df.fillna('Indisponível')
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 52242               52242                INCIDENTE
# 1                 45331               45331                 ACIDENTE
# 2                 45333               45333                 ACIDENTE
# 3                 45401               45401                 ACIDENTE
# 4                 45407               45407                 ACIDENTE
# ...                 ...                 ...                      ...
# 5162              80458               80458                 ACIDENTE
# 5163              80452               80452                 ACIDENTE
# 5164              80457               80457          INCIDENTE GRAVE
# 5165              80460               80460                INCIDENTE
# 5166              80467               80467                INCIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0         PORTO ALEGRE            RS                 SBPA     2012-01-05
# 1            GUARULHOS            SP                 SBGR     2012-01-06
# 2               VIAMÃO            RS         Indisponível     2012-01-06
# 3        SÃO SEBASTIÃO            SP         Indisponível     2012-01-06
# 4             SÃO SEPÉ            RS         Indisponível     2012-01-06
# ...                ...           ...                  ...            ...
# 5162             JATAÍ            GO         Indisponível     2021-12-30
# 5163           MARACAÍ            SP         Indisponível     2021-12-31
# 5164     NOVO HAMBURGO            RS                 SSNH     2021-12-31
# 5165          CURITIBA            PR                 SBBI     2021-12-31
# 5166         PETROLINA            PE                 SBPL     2021-12-31
#
#      ocorrencia_hora  total_recomendacoes
# 0           20:27:00                    0
# 1           13:44:00                    3
# 2           13:00:00                    0
# 3           17:00:00                    0
# 4           16:30:00                    0
# ...              ...                  ...
# 5162        20:30:00                    0
# 5163        09:30:00                    0
# 5164        11:59:00                    0
# 5165        15:12:00                    0
# 5166        20:30:00                    0
#
# [5167 rows x 9 columns]

# %%
df.fillna('Indisponível').isnull().sum()
# Out:
# codigo_ocorrencia           0
# codigo_ocorrencia2          0
# ocorrencia_classificacao    0
# ocorrencia_cidade           0
# ocorrencia_uf               0
# ocorrencia_aerodromo        0
# ocorrencia_dia              0
# ocorrencia_hora             0
# total_recomendacoes         0
# dtype: int64

# %% [markdown]
# Os valores indisponíveis por coluna podem ser substituídos usando um comando similar ao informado abaixo. Nesse exemplo, valores indisponíveis na coluna 'total_recomendacoes' são substituídos pelo valor 10. A alteração pode ser efetivamente feita no dataframe ao fazer uso do parâmetro **inplace=True**.

# %%
df.fillna(value={'ocorrencia_aerodromo':10})
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 52242               52242                INCIDENTE
# 1                 45331               45331                 ACIDENTE
# 2                 45333               45333                 ACIDENTE
# 3                 45401               45401                 ACIDENTE
# 4                 45407               45407                 ACIDENTE
# ...                 ...                 ...                      ...
# 5162              80458               80458                 ACIDENTE
# 5163              80452               80452                 ACIDENTE
# 5164              80457               80457          INCIDENTE GRAVE
# 5165              80460               80460                INCIDENTE
# 5166              80467               80467                INCIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0         PORTO ALEGRE            RS                 SBPA     2012-01-05
# 1            GUARULHOS            SP                 SBGR     2012-01-06
# 2               VIAMÃO            RS                   10     2012-01-06
# 3        SÃO SEBASTIÃO            SP                   10     2012-01-06
# 4             SÃO SEPÉ            RS                   10     2012-01-06
# ...                ...           ...                  ...            ...
# 5162             JATAÍ            GO                   10     2021-12-30
# 5163           MARACAÍ            SP                   10     2021-12-31
# 5164     NOVO HAMBURGO            RS                 SSNH     2021-12-31
# 5165          CURITIBA            PR                 SBBI     2021-12-31
# 5166         PETROLINA            PE                 SBPL     2021-12-31
#
#      ocorrencia_hora  total_recomendacoes
# 0           20:27:00                    0
# 1           13:44:00                    3
# 2           13:00:00                    0
# 3           17:00:00                    0
# 4           16:30:00                    0
# ...              ...                  ...
# 5162        20:30:00                    0
# 5163        09:30:00                    0
# 5164        11:59:00                    0
# 5165        15:12:00                    0
# 5166        20:30:00                    0
#
# [5167 rows x 9 columns]

# %% [markdown]
# **Sugestão do professor:** Antes de uma alteração em uma coluna inteira, uma coluna de backup pode ser criada por meio do comando abaixo:

# %%
df['total_recomendacoes_bkp'] = df.total_recomendacoes

# %%
df
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 52242               52242                INCIDENTE
# 1                 45331               45331                 ACIDENTE
# 2                 45333               45333                 ACIDENTE
# 3                 45401               45401                 ACIDENTE
# 4                 45407               45407                 ACIDENTE
# ...                 ...                 ...                      ...
# 5162              80458               80458                 ACIDENTE
# 5163              80452               80452                 ACIDENTE
# 5164              80457               80457          INCIDENTE GRAVE
# 5165              80460               80460                INCIDENTE
# 5166              80467               80467                INCIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0         PORTO ALEGRE            RS                 SBPA     2012-01-05
# 1            GUARULHOS            SP                 SBGR     2012-01-06
# 2               VIAMÃO            RS                 <NA>     2012-01-06
# 3        SÃO SEBASTIÃO            SP                 <NA>     2012-01-06
# 4             SÃO SEPÉ            RS                 <NA>     2012-01-06
# ...                ...           ...                  ...            ...
# 5162             JATAÍ            GO                 <NA>     2021-12-30
# 5163           MARACAÍ            SP                 <NA>     2021-12-31
# 5164     NOVO HAMBURGO            RS                 SSNH     2021-12-31
# 5165          CURITIBA            PR                 SBBI     2021-12-31
# 5166         PETROLINA            PE                 SBPL     2021-12-31
#
#      ocorrencia_hora  total_recomendacoes  total_recomendacoes_bkp
# 0           20:27:00                    0                        0
# 1           13:44:00                    3                        3
# 2           13:00:00                    0                        0
# 3           17:00:00                    0                        0
# 4           16:30:00                    0                        0
# ...              ...                  ...                      ...
# 5162        20:30:00                    0                        0
# 5163        09:30:00                    0                        0
# 5164        11:59:00                    0                        0
# 5165        15:12:00                    0                        0
# 5166        20:30:00                    0                        0
#
# [5167 rows x 10 columns]

# %% [markdown]
# Colunas ou linhas podem ser removidas do dataframe por meio da função ***drop()***. Uma lista de linhas/colunas deve ser informada e o parâmetro ***axis=0*** indica que linhas serão removidas e o parâmetro ***axis=1*** indica que colunas serão removidas. Para a alteração efetiva do dataframe o parametro ***inplace=True*** deve ser usado.

# %%
df.drop(['total_recomendacoes_bkp'], axis=1, inplace=True)

# %%
df
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 52242               52242                INCIDENTE
# 1                 45331               45331                 ACIDENTE
# 2                 45333               45333                 ACIDENTE
# 3                 45401               45401                 ACIDENTE
# 4                 45407               45407                 ACIDENTE
# ...                 ...                 ...                      ...
# 5162              80458               80458                 ACIDENTE
# 5163              80452               80452                 ACIDENTE
# 5164              80457               80457          INCIDENTE GRAVE
# 5165              80460               80460                INCIDENTE
# 5166              80467               80467                INCIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0         PORTO ALEGRE            RS                 SBPA     2012-01-05
# 1            GUARULHOS            SP                 SBGR     2012-01-06
# 2               VIAMÃO            RS                 <NA>     2012-01-06
# 3        SÃO SEBASTIÃO            SP                 <NA>     2012-01-06
# 4             SÃO SEPÉ            RS                 <NA>     2012-01-06
# ...                ...           ...                  ...            ...
# 5162             JATAÍ            GO                 <NA>     2021-12-30
# 5163           MARACAÍ            SP                 <NA>     2021-12-31
# 5164     NOVO HAMBURGO            RS                 SSNH     2021-12-31
# 5165          CURITIBA            PR                 SBBI     2021-12-31
# 5166         PETROLINA            PE                 SBPL     2021-12-31
#
#      ocorrencia_hora  total_recomendacoes
# 0           20:27:00                    0
# 1           13:44:00                    3
# 2           13:00:00                    0
# 3           17:00:00                    0
# 4           16:30:00                    0
# ...              ...                  ...
# 5162        20:30:00                    0
# 5163        09:30:00                    0
# 5164        11:59:00                    0
# 5165        15:12:00                    0
# 5166        20:30:00                    0
#
# [5167 rows x 9 columns]

# %% [markdown]
# Linhas contendo valores indisponíveis podem ser removidas do dataframe por meio da função ***df.dropna()***. O dataframe pode ser efetivamente alterado ao se fazer uso do parâmetro ***inplace=True***

# %%
df.dropna().isna().sum()
# Out:
# codigo_ocorrencia           0
# codigo_ocorrencia2          0
# ocorrencia_classificacao    0
# ocorrencia_cidade           0
# ocorrencia_uf               0
# ocorrencia_aerodromo        0
# ocorrencia_dia              0
# ocorrencia_hora             0
# total_recomendacoes         0
# dtype: int64

# %% [markdown]
# As linhas a serem removidas podem ser filtradas ao se fazer uso do parâmetro ***subset*** conforme exemplo abaixo:

# %%
df.dropna(subset=['ocorrencia_uf'])
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 52242               52242                INCIDENTE
# 1                 45331               45331                 ACIDENTE
# 2                 45333               45333                 ACIDENTE
# 3                 45401               45401                 ACIDENTE
# 4                 45407               45407                 ACIDENTE
# ...                 ...                 ...                      ...
# 5162              80458               80458                 ACIDENTE
# 5163              80452               80452                 ACIDENTE
# 5164              80457               80457          INCIDENTE GRAVE
# 5165              80460               80460                INCIDENTE
# 5166              80467               80467                INCIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0         PORTO ALEGRE            RS                 SBPA     2012-01-05
# 1            GUARULHOS            SP                 SBGR     2012-01-06
# 2               VIAMÃO            RS                 <NA>     2012-01-06
# 3        SÃO SEBASTIÃO            SP                 <NA>     2012-01-06
# 4             SÃO SEPÉ            RS                 <NA>     2012-01-06
# ...                ...           ...                  ...            ...
# 5162             JATAÍ            GO                 <NA>     2021-12-30
# 5163           MARACAÍ            SP                 <NA>     2021-12-31
# 5164     NOVO HAMBURGO            RS                 SSNH     2021-12-31
# 5165          CURITIBA            PR                 SBBI     2021-12-31
# 5166         PETROLINA            PE                 SBPL     2021-12-31
#
#      ocorrencia_hora  total_recomendacoes
# 0           20:27:00                    0
# 1           13:44:00                    3
# 2           13:00:00                    0
# 3           17:00:00                    0
# 4           16:30:00                    0
# ...              ...                  ...
# 5162        20:30:00                    0
# 5163        09:30:00                    0
# 5164        11:59:00                    0
# 5165        15:12:00                    0
# 5166        20:30:00                    0
#
# [5165 rows x 9 columns]

# %% [markdown]
# Nesse caso, se houver uma ocorrência de dado indisponível na coluna informada, a linha na qual o dado se encontra será removida.

# %% [markdown]
# Linhas duplicadas do dataframe podem ser removidas com o comando abaixo. Para alterar o dataframe ***inplace=True*** deve ser usado como parâmetro.

# %%
df.drop_duplicates()
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 52242               52242                INCIDENTE
# 1                 45331               45331                 ACIDENTE
# 2                 45333               45333                 ACIDENTE
# 3                 45401               45401                 ACIDENTE
# 4                 45407               45407                 ACIDENTE
# ...                 ...                 ...                      ...
# 5162              80458               80458                 ACIDENTE
# 5163              80452               80452                 ACIDENTE
# 5164              80457               80457          INCIDENTE GRAVE
# 5165              80460               80460                INCIDENTE
# 5166              80467               80467                INCIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0         PORTO ALEGRE            RS                 SBPA     2012-01-05
# 1            GUARULHOS            SP                 SBGR     2012-01-06
# 2               VIAMÃO            RS                 <NA>     2012-01-06
# 3        SÃO SEBASTIÃO            SP                 <NA>     2012-01-06
# 4             SÃO SEPÉ            RS                 <NA>     2012-01-06
# ...                ...           ...                  ...            ...
# 5162             JATAÍ            GO                 <NA>     2021-12-30
# 5163           MARACAÍ            SP                 <NA>     2021-12-31
# 5164     NOVO HAMBURGO            RS                 SSNH     2021-12-31
# 5165          CURITIBA            PR                 SBBI     2021-12-31
# 5166         PETROLINA            PE                 SBPL     2021-12-31
#
#      ocorrencia_hora  total_recomendacoes
# 0           20:27:00                    0
# 1           13:44:00                    3
# 2           13:00:00                    0
# 3           17:00:00                    0
# 4           16:30:00                    0
# ...              ...                  ...
# 5162        20:30:00                    0
# 5163        09:30:00                    0
# 5164        11:59:00                    0
# 5165        15:12:00                    0
# 5166        20:30:00                    0
#
# [5167 rows x 9 columns]

# %% [markdown]
# <h1>Transformação de dados</h1>

# %% [markdown]
# Durante a etapa de extração de dados, uma lista de valores considerados como não disponíveis pode ser fornecido como parâmetro. Dessa forma cada ocorrência desses valores será substituída por NA (*Not available*). Segue código abaixo:

# %%
valores_ausentes = ['**','###!','####','****','*****','NULL']
df = pd.read_csv("ocorrencia.csv", sep = ';', date_parser = lambda arg : pd.to_datetime(arg, format="%d/%m/%Y"), parse_dates=['ocorrencia_dia'], na_values=valores_ausentes)
df.head(10)
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              52242               52242                INCIDENTE
# 1              45331               45331                 ACIDENTE
# 2              45333               45333                 ACIDENTE
# 3              45401               45401                 ACIDENTE
# 4              45407               45407                 ACIDENTE
# 5              52243               52243                INCIDENTE
# 6              50713               50713          INCIDENTE GRAVE
# 7              45334               45334                INCIDENTE
# 8              45391               45391                 ACIDENTE
# 9              52244               52244                INCIDENTE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0           PORTO ALEGRE            RS                 SBPA     2012-01-05
# 1              GUARULHOS            SP                 SBGR     2012-01-06
# 2                 VIAMÃO            RS                  NaN     2012-01-06
# 3          SÃO SEBASTIÃO            SP                  NaN     2012-01-06
# 4               SÃO SEPÉ            RS                  NaN     2012-01-06
# 5                UBATUBA            SP                  NaN     2012-01-06
# 6               CAMPINAS            SP                 SDAI     2012-01-07
# 7                  BELÉM            PA                 SBBE     2012-01-08
# 8  CONCEIÇÃO DAS ALAGOAS            MG                  NaN     2012-01-08
# 9             UBERLÂNDIA            MG                 SBUL     2012-01-08
#
#   ocorrencia_hora  total_recomendacoes
# 0        20:27:00                    0
# 1        13:44:00                    3
# 2        13:00:00                    0
# 3        17:00:00                    0
# 4        16:30:00                    0
# 5        14:30:00                    0
# 6        18:15:00                    0
# 7        19:12:00                    0
# 8        16:00:00                    0
# 9        22:13:00                    0

# %% [markdown]
# **Obs:** Assim como NA (*Not available*), NaN (*Not a Numeric*) é considerado um "*missing data*"

# %% [markdown]
# Diferente do observado em casos anteriores, uma limpeza dos *missing values* é feita na etapa de extração, portanto o schema para validação deve considerar as colunas que podem conter missing values. Para isso deve-se usar ***nullable=True*** conforme exemplificado abaixo:

# %%
schema = pa.DataFrameSchema(
    columns = {
        "codigo_ocorrencia":pa.Column(pa.Int),
        "codigo_ocorrencia2":pa.Column(pa.Int),
        "ocorrencia_classificacao":pa.Column(pa.String),
        "ocorrencia_cidade":pa.Column(pa.String),
        "ocorrencia_uf":pa.Column(pa.String, pa.Check.str_length(2, 2), nullable=True),
        "ocorrencia_aerodromo":pa.Column(pa.String, nullable=True),
        "ocorrencia_dia":pa.Column(pa.DateTime),
        "ocorrencia_hora":pa.Column(pa.String, pa.Check.str_matches(r'^([0-1]?[0-9]|[2][0-3]):([0-5][0-9])(:[0-5][0-9])?$'),nullable=True),
        "total_recomendacoes":pa.Column(pa.Int)
    }
)

# %%
schema.validate(df)
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 52242               52242                INCIDENTE
# 1                 45331               45331                 ACIDENTE
# 2                 45333               45333                 ACIDENTE
# 3                 45401               45401                 ACIDENTE
# 4                 45407               45407                 ACIDENTE
# ...                 ...                 ...                      ...
# 5162              80458               80458                 ACIDENTE
# 5163              80452               80452                 ACIDENTE
# 5164              80457               80457          INCIDENTE GRAVE
# 5165              80460               80460                INCIDENTE
# 5166              80467               80467                INCIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0         PORTO ALEGRE            RS                 SBPA     2012-01-05
# 1            GUARULHOS            SP                 SBGR     2012-01-06
# 2               VIAMÃO            RS                  NaN     2012-01-06
# 3        SÃO SEBASTIÃO            SP                  NaN     2012-01-06
# 4             SÃO SEPÉ            RS                  NaN     2012-01-06
# ...                ...           ...                  ...            ...
# 5162             JATAÍ            GO                  NaN     2021-12-30
# 5163           MARACAÍ            SP                  NaN     2021-12-31
# 5164     NOVO HAMBURGO            RS                 SSNH     2021-12-31
# 5165          CURITIBA            PR                 SBBI     2021-12-31
# 5166         PETROLINA            PE                 SBPL     2021-12-31
#
#      ocorrencia_hora  total_recomendacoes
# 0           20:27:00                    0
# 1           13:44:00                    3
# 2           13:00:00                    0
# 3           17:00:00                    0
# 4           16:30:00                    0
# ...              ...                  ...
# 5162        20:30:00                    0
# 5163        09:30:00                    0
# 5164        11:59:00                    0
# 5165        15:12:00                    0
# 5166        20:30:00                    0
#
# [5167 rows x 9 columns]

# %% [markdown]
# **Nota:** Valores das linhas podem ser obtidos fazendo-se referência ao label com o uso de ***loc[]***. Outra forma de obter valores das linhas é por meio de índices (análogo ao feito com listas). Para isso usa-se a property ***iloc[]***. O código abaixo exemplifica como se pode obter a última linha do dataframe:

# %%
df.iloc[-1]
# Out:
# codigo_ocorrencia                         80467
# codigo_ocorrencia2                        80467
# ocorrencia_classificacao              INCIDENTE
# ocorrencia_cidade                     PETROLINA
# ocorrencia_uf                                PE
# ocorrencia_aerodromo                       SBPL
# ocorrencia_dia              2021-12-31 00:00:00
# ocorrencia_hora                        20:30:00
# total_recomendacoes                           0
# Name: 5166, dtype: object

# %% [markdown]
# O uso de slicing também é possível. Mas o resultado difere entre ***loc[]*** e ***iloc[]*** como pode ser observado abaixo:

# %%
df.loc[10:15]
# Out:
#     codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 10              45332               45332                 ACIDENTE
# 11              52245               52245                INCIDENTE
# 12              45396               45396          INCIDENTE GRAVE
# 13              45408               45408                 ACIDENTE
# 14              45447               45447                INCIDENTE
# 15              45409               45409                 ACIDENTE
#
#    ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 10            VIAMÃO            RS                  NaN     2012-01-09
# 11      PORTO ALEGRE            RS                 SBPA     2012-01-09
# 12            MARABÁ            PA                 SBMA     2012-01-11
# 13          ELDORADO            SP                  NaN     2012-01-11
# 14        RIO BRANCO            AC                  NaN     2012-01-13
# 15           CÁCERES            MT                  NaN     2012-01-14
#
#    ocorrencia_hora  total_recomendacoes
# 10        13:30:00                    0
# 11        13:36:00                    0
# 12        11:21:00                    0
# 13        13:45:00                    1
# 14        18:15:00                    0
# 15        10:00:00                    0

# %%
df.iloc[10:15]
# Out:
#     codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 10              45332               45332                 ACIDENTE
# 11              52245               52245                INCIDENTE
# 12              45396               45396          INCIDENTE GRAVE
# 13              45408               45408                 ACIDENTE
# 14              45447               45447                INCIDENTE
#
#    ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 10            VIAMÃO            RS                  NaN     2012-01-09
# 11      PORTO ALEGRE            RS                 SBPA     2012-01-09
# 12            MARABÁ            PA                 SBMA     2012-01-11
# 13          ELDORADO            SP                  NaN     2012-01-11
# 14        RIO BRANCO            AC                  NaN     2012-01-13
#
#    ocorrencia_hora  total_recomendacoes
# 10        13:30:00                    0
# 11        13:36:00                    0
# 12        11:21:00                    0
# 13        13:45:00                    1
# 14        18:15:00                    0

# %% [markdown]
# A função ***isna()*** também funciona em *missing values* como NaN. Segue exemplo abaixo:

# %%
df.isna().sum()
# Out:
# codigo_ocorrencia              0
# codigo_ocorrencia2             0
# ocorrencia_classificacao       0
# ocorrencia_cidade              0
# ocorrencia_uf                  2
# ocorrencia_aerodromo        1905
# ocorrencia_dia                 0
# ocorrencia_hora                1
# total_recomendacoes            0
# dtype: int64

# %% [markdown]
# O código abaixo verifica todos os elementos de uma coluna e se for ***True***, temos um *missing value*

# %%
df.ocorrencia_uf.isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 5162    False
# 5163    False
# 5164    False
# 5165    False
# 5166    False
# Name: ocorrencia_uf, Length: 5167, dtype: bool

# %% [markdown]
# Outro exemplo, o comando abaixo retorna linhas que contenham *missing values* na coluna informada.

# %%
filtro = df.ocorrencia_uf.isnull()
df.loc[filtro]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 1099              49474               49474                 ACIDENTE
# 4728              79956               79956                 ACIDENTE
#
#          ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 1099  ÁGUAS INTERNACIONAIS           NaN                  NaN     2013-09-02
# 4728      NÃO IDENTIFICADA           NaN                  NaN     2021-02-26
#
#      ocorrencia_hora  total_recomendacoes
# 1099        02:54:00                    0
# 4728        11:00:00                    0

# %% [markdown]
# Número de valores informados por coluna pode ser obtido por chamada a função ***count()***

# %%
df.count()
# Out:
# codigo_ocorrencia           5167
# codigo_ocorrencia2          5167
# ocorrencia_classificacao    5167
# ocorrencia_cidade           5167
# ocorrencia_uf               5165
# ocorrencia_aerodromo        3262
# ocorrencia_dia              5167
# ocorrencia_hora             5166
# total_recomendacoes         5167
# ocorrencia_dia_hora         5166
# dtype: int64

# %% [markdown]
# <h3> Filtros </h3>

# %% [markdown]
# Uso de filtros é usado para restringir resultados de uma consulta no dataframe, obtendo assim um conjunto de dados e novas informações. Por exemplo, abaixo temos ocorrencias em que total_recomendacoes é maior que 10.

# %%
filtro = df.total_recomendacoes > 10
df.loc[filtro, ['ocorrencia_cidade','total_recomendacoes']]
# Out:
#      ocorrencia_cidade  total_recomendacoes
# 844           BRASÍLIA                   11
# 1669            SANTOS                   13
# 2804           VITÓRIA                   12

# %% [markdown]
# Abaixo como exemplo, temos as ocorrências cuja classificação é de INCIDENTE GRAVE

# %%
filtro = df.ocorrencia_classificacao == 'INCIDENTE GRAVE'
df.loc[filtro, ['ocorrencia_cidade','total_recomendacoes']]
# Out:
#         ocorrencia_cidade  total_recomendacoes
# 6                CAMPINAS                    0
# 12                 MARABÁ                    0
# 18                CAMOCIM                    0
# 19                  MUANÁ                    0
# 24           RONDONÓPOLIS                    0
# ...                   ...                  ...
# 5139    NOVA BANDEIRANTES                    0
# 5146  FORMOSO DO ARAGUAIA                    0
# 5158            ARAÇATUBA                    0
# 5159           SANTA RITA                    0
# 5164        NOVO HAMBURGO                    0
#
# [691 rows x 2 columns]

# %% [markdown]
# <h5>Combinando mais de um filtro</h5>

# %% [markdown]
# Operadores lógicos podem ser usados para vários filtros. Abaixo seguem vários exemplos aplicando operadores lógicos como and (&) e or (|).

# %%
filtro1 = df.ocorrencia_classificacao == 'INCIDENTE GRAVE'
filtro2 = df.ocorrencia_uf == 'SP'
df.loc[filtro1 & filtro2]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 6                 50713               50713          INCIDENTE GRAVE
# 78                45598               45598          INCIDENTE GRAVE
# 86                45653               45653          INCIDENTE GRAVE
# 91                45599               45599          INCIDENTE GRAVE
# 140               45651               45651          INCIDENTE GRAVE
# ...                 ...                 ...                      ...
# 4954              80200               80200          INCIDENTE GRAVE
# 4980              80238               80238          INCIDENTE GRAVE
# 5003              80265               80265          INCIDENTE GRAVE
# 5098              80382               80382          INCIDENTE GRAVE
# 5158              80454               80454          INCIDENTE GRAVE
#
#       ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 6              CAMPINAS            SP                 SDAI     2012-01-07
# 78    BRAGANÇA PAULISTA            SP                 SBBP     2012-02-20
# 86            GUARULHOS            SP                 SBGR     2012-02-24
# 91    BRAGANÇA PAULISTA            SP                 SBBP     2012-02-27
# 140                 ITU            SP                  NaN     2012-03-24
# ...                 ...           ...                  ...            ...
# 4954  BRAGANÇA PAULISTA            SP                 SDVH     2021-07-25
# 4980        VOTUPORANGA            SP                 SDVG     2021-08-11
# 5003          SÃO PAULO            SP                 SBMT     2021-08-31
# 5098         PIRACICABA            SP                 SDPW     2021-11-16
# 5158          ARAÇATUBA            SP                 SBAU     2021-12-29
#
#      ocorrencia_hora  total_recomendacoes ocorrencia_dia_hora
# 6           18:15:00                    0 2012-01-07 18:15:00
# 78          14:10:00                    0 2012-02-20 14:10:00
# 86          20:04:00                    0 2012-02-24 20:04:00
# 91          19:15:00                    0 2012-02-27 19:15:00
# 140         20:45:00                    1 2012-03-24 20:45:00
# ...              ...                  ...                 ...
# 4954        12:25:00                    0 2021-07-25 12:25:00
# 4980        19:09:00                    0 2021-08-11 19:09:00
# 5003        16:50:00                    0 2021-08-31 16:50:00
# 5098        20:50:00                    0 2021-11-16 20:50:00
# 5158        21:35:00                    0 2021-12-29 21:35:00
#
# [132 rows x 10 columns]

# %%
#ocorrencias cuja classificacao == INCIDENTE GRAVE ou estado == SP
filtro1 = df.ocorrencia_classificacao == 'INCIDENTE GRAVE'
filtro2 = df.ocorrencia_uf == 'SP'
df.loc[filtro1 | filtro2]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 1                 45331               45331                 ACIDENTE
# 3                 45401               45401                 ACIDENTE
# 5                 52243               52243                INCIDENTE
# 6                 50713               50713          INCIDENTE GRAVE
# 12                45396               45396          INCIDENTE GRAVE
# ...                 ...                 ...                      ...
# 5158              80454               80454          INCIDENTE GRAVE
# 5159              80455               80455          INCIDENTE GRAVE
# 5161              80456               80456                INCIDENTE
# 5163              80452               80452                 ACIDENTE
# 5164              80457               80457          INCIDENTE GRAVE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 1            GUARULHOS            SP                 SBGR     2012-01-06
# 3        SÃO SEBASTIÃO            SP                  NaN     2012-01-06
# 5              UBATUBA            SP                  NaN     2012-01-06
# 6             CAMPINAS            SP                 SDAI     2012-01-07
# 12              MARABÁ            PA                 SBMA     2012-01-11
# ...                ...           ...                  ...            ...
# 5158         ARAÇATUBA            SP                 SBAU     2021-12-29
# 5159        SANTA RITA            PB                  NaN     2021-12-29
# 5161         SÃO PAULO            SP                 SBSP     2021-12-30
# 5163           MARACAÍ            SP                  NaN     2021-12-31
# 5164     NOVO HAMBURGO            RS                 SSNH     2021-12-31
#
#      ocorrencia_hora  total_recomendacoes ocorrencia_dia_hora
# 1           13:44:00                    3 2012-01-06 13:44:00
# 3           17:00:00                    0 2012-01-06 17:00:00
# 5           14:30:00                    0 2012-01-06 14:30:00
# 6           18:15:00                    0 2012-01-07 18:15:00
# 12          11:21:00                    0 2012-01-11 11:21:00
# ...              ...                  ...                 ...
# 5158        21:35:00                    0 2021-12-29 21:35:00
# 5159        18:50:00                    0 2021-12-29 18:50:00
# 5161        13:15:00                    0 2021-12-30 13:15:00
# 5163        09:30:00                    0 2021-12-31 09:30:00
# 5164        11:59:00                    0 2021-12-31 11:59:00
#
# [1820 rows x 10 columns]

# %%
#ocorrencias cuja (classificacao == INCIDENTE GRAVE ou classificacao == INCIDENTE) e estado == SP
filtro1 = (df.ocorrencia_classificacao == 'INCIDENTE GRAVE') | (df.ocorrencia_classificacao == 'INCIDENTE')
filtro2 = df.ocorrencia_uf == 'SP'
df.loc[filtro1 & filtro2]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 5                 52243               52243                INCIDENTE
# 6                 50713               50713          INCIDENTE GRAVE
# 28                52248               52248                INCIDENTE
# 35                52054               52054                INCIDENTE
# 36                52055               52055                INCIDENTE
# ...                 ...                 ...                      ...
# 5134              80425               80425                INCIDENTE
# 5143              80431               80431                INCIDENTE
# 5157              80453               80453                INCIDENTE
# 5158              80454               80454          INCIDENTE GRAVE
# 5161              80456               80456                INCIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 5              UBATUBA            SP                  NaN     2012-01-06
# 6             CAMPINAS            SP                 SDAI     2012-01-07
# 28           SÃO PAULO            SP                 SBMT     2012-01-21
# 35           SÃO PAULO            SP                 SBMT     2012-01-25
# 36      RIBEIRÃO PRETO            SP                  NaN     2012-01-25
# ...                ...           ...                  ...            ...
# 5134         SÃO PAULO            SP                 SBSP     2021-12-09
# 5143            SANTOS            SP                 SBST     2021-12-15
# 5157          CAMPINAS            SP                 SBKP     2021-12-29
# 5158         ARAÇATUBA            SP                 SBAU     2021-12-29
# 5161         SÃO PAULO            SP                 SBSP     2021-12-30
#
#      ocorrencia_hora  total_recomendacoes ocorrencia_dia_hora
# 5           14:30:00                    0 2012-01-06 14:30:00
# 6           18:15:00                    0 2012-01-07 18:15:00
# 28          11:15:00                    0 2012-01-21 11:15:00
# 35          23:00:00                    0 2012-01-25 23:00:00
# 36          09:30:00                    0 2012-01-25 09:30:00
# ...              ...                  ...                 ...
# 5134        20:30:00                    0 2021-12-09 20:30:00
# 5143        12:30:00                    0 2021-12-15 12:30:00
# 5157        09:00:00                    0 2021-12-29 09:00:00
# 5158        21:35:00                    0 2021-12-29 21:35:00
# 5161        13:15:00                    0 2021-12-30 13:15:00
#
# [913 rows x 10 columns]

# %% [markdown]
# O filtro com operador or ( | ) pode ser substituído pelo uso da função ***isin()***. Essa função recebe como parâmetro uma lista dos valores a considerar para a coluna informada. Segue exemplo abaixo:

# %%
#ocorrencias cuja (classificacao == INCIDENTE GRAVE ou classificacao == INCIDENTE) e estado == SP
filtro1 = df.ocorrencia_classificacao.isin(['INCIDENTE GRAVE', 'INCIDENTE'])
filtro2 = df.ocorrencia_uf == 'SP'
df.loc[filtro1 & filtro2]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 5                 52243               52243                INCIDENTE
# 6                 50713               50713          INCIDENTE GRAVE
# 28                52248               52248                INCIDENTE
# 35                52054               52054                INCIDENTE
# 36                52055               52055                INCIDENTE
# ...                 ...                 ...                      ...
# 5134              80425               80425                INCIDENTE
# 5143              80431               80431                INCIDENTE
# 5157              80453               80453                INCIDENTE
# 5158              80454               80454          INCIDENTE GRAVE
# 5161              80456               80456                INCIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 5              UBATUBA            SP                  NaN     2012-01-06
# 6             CAMPINAS            SP                 SDAI     2012-01-07
# 28           SÃO PAULO            SP                 SBMT     2012-01-21
# 35           SÃO PAULO            SP                 SBMT     2012-01-25
# 36      RIBEIRÃO PRETO            SP                  NaN     2012-01-25
# ...                ...           ...                  ...            ...
# 5134         SÃO PAULO            SP                 SBSP     2021-12-09
# 5143            SANTOS            SP                 SBST     2021-12-15
# 5157          CAMPINAS            SP                 SBKP     2021-12-29
# 5158         ARAÇATUBA            SP                 SBAU     2021-12-29
# 5161         SÃO PAULO            SP                 SBSP     2021-12-30
#
#      ocorrencia_hora  total_recomendacoes ocorrencia_dia_hora
# 5           14:30:00                    0 2012-01-06 14:30:00
# 6           18:15:00                    0 2012-01-07 18:15:00
# 28          11:15:00                    0 2012-01-21 11:15:00
# 35          23:00:00                    0 2012-01-25 23:00:00
# 36          09:30:00                    0 2012-01-25 09:30:00
# ...              ...                  ...                 ...
# 5134        20:30:00                    0 2021-12-09 20:30:00
# 5143        12:30:00                    0 2021-12-15 12:30:00
# 5157        09:00:00                    0 2021-12-29 09:00:00
# 5158        21:35:00                    0 2021-12-29 21:35:00
# 5161        13:15:00                    0 2021-12-30 13:15:00
#
# [913 rows x 10 columns]

# %% [markdown]
# <h5>Avaliando parte do conteúdo </h5>

# %%
#ocorrencias cuja cidade começam com a letra C
filtro = df.ocorrencia_cidade.str[0] == 'C'
df.loc[filtro]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 6                 50713               50713          INCIDENTE GRAVE
# 8                 45391               45391                 ACIDENTE
# 15                45409               45409                 ACIDENTE
# 18                50714               50714          INCIDENTE GRAVE
# 22                45390               45390                 ACIDENTE
# ...                 ...                 ...                      ...
# 5142              80434               80434                 ACIDENTE
# 5144              80447               80447                INCIDENTE
# 5150              80445               80445                 ACIDENTE
# 5157              80453               80453                INCIDENTE
# 5165              80460               80460                INCIDENTE
#
#           ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 6                  CAMPINAS            SP                 SDAI     2012-01-07
# 8     CONCEIÇÃO DAS ALAGOAS            MG                  NaN     2012-01-08
# 15                  CÁCERES            MT                  NaN     2012-01-14
# 18                  CAMOCIM            CE                 SNWC     2012-01-17
# 22        CACHOEIRA DOURADA            GO                  NaN     2012-01-20
# ...                     ...           ...                  ...            ...
# 5142                CARACOL            MS                  NaN     2021-12-14
# 5144                CONFINS            MG                 SBCF     2021-12-15
# 5150            CHUPINGUAIA            RO                  NaN     2021-12-20
# 5157               CAMPINAS            SP                 SBKP     2021-12-29
# 5165               CURITIBA            PR                 SBBI     2021-12-31
#
#      ocorrencia_hora  total_recomendacoes ocorrencia_dia_hora
# 6           18:15:00                    0 2012-01-07 18:15:00
# 8           16:00:00                    0 2012-01-08 16:00:00
# 15          10:00:00                    0 2012-01-14 10:00:00
# 18          18:25:00                    0 2012-01-17 18:25:00
# 22          21:00:00                    0 2012-01-20 21:00:00
# ...              ...                  ...                 ...
# 5142        21:35:00                    0 2021-12-14 21:35:00
# 5144        17:10:00                    0 2021-12-15 17:10:00
# 5150        12:05:00                    0 2021-12-20 12:05:00
# 5157        09:00:00                    0 2021-12-29 09:00:00
# 5165        15:12:00                    0 2021-12-31 15:12:00
#
# [771 rows x 10 columns]

# %%
#ocorrencias cuja cidade termina com a letra A
filtro = df.ocorrencia_cidade.str[-1] == 'A'
df.loc[filtro]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 5                 52243               52243                INCIDENTE
# 9                 52244               52244                INCIDENTE
# 17                52246               52246                INCIDENTE
# 21                45392               45392                 ACIDENTE
# 22                45390               45390                 ACIDENTE
# ...                 ...                 ...                      ...
# 5152              80465               80465                INCIDENTE
# 5158              80454               80454          INCIDENTE GRAVE
# 5159              80455               80455          INCIDENTE GRAVE
# 5165              80460               80460                INCIDENTE
# 5166              80467               80467                INCIDENTE
#
#       ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 5               UBATUBA            SP                  NaN     2012-01-06
# 9            UBERLÂNDIA            MG                 SBUL     2012-01-08
# 17             BRASÍLIA            DF                 SBBR     2012-01-16
# 21             BRASÍLIA            DF                  NaN     2012-01-19
# 22    CACHOEIRA DOURADA            GO                  NaN     2012-01-20
# ...                 ...           ...                  ...            ...
# 5152            VITÓRIA            ES                 SBVT     2021-12-21
# 5158          ARAÇATUBA            SP                 SBAU     2021-12-29
# 5159         SANTA RITA            PB                  NaN     2021-12-29
# 5165           CURITIBA            PR                 SBBI     2021-12-31
# 5166          PETROLINA            PE                 SBPL     2021-12-31
#
#      ocorrencia_hora  total_recomendacoes ocorrencia_dia_hora
# 5           14:30:00                    0 2012-01-06 14:30:00
# 9           22:13:00                    0 2012-01-08 22:13:00
# 17          16:47:00                    0 2012-01-16 16:47:00
# 21          21:30:00                    2 2012-01-19 21:30:00
# 22          21:00:00                    0 2012-01-20 21:00:00
# ...              ...                  ...                 ...
# 5152        22:25:00                    0 2021-12-21 22:25:00
# 5158        21:35:00                    0 2021-12-29 21:35:00
# 5159        18:50:00                    0 2021-12-29 18:50:00
# 5165        15:12:00                    0 2021-12-31 15:12:00
# 5166        20:30:00                    0 2021-12-31 20:30:00
#
# [1386 rows x 10 columns]

# %%
#ocorrencias cuja cidade termina com a substring NA
filtro = df.ocorrencia_cidade.str[-2:] == 'NA'
df.loc[filtro]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 51                45587               45587                 ACIDENTE
# 52                52056               52056                INCIDENTE
# 54                45572               45572                 ACIDENTE
# 113               45612               45612                INCIDENTE
# 172               45750               45750                 ACIDENTE
# ...                 ...                 ...                      ...
# 5040              80311               80311                 ACIDENTE
# 5045              80323               80323                INCIDENTE
# 5068              80348               80348                 ACIDENTE
# 5100              80394               80394                INCIDENTE
# 5166              80467               80467                INCIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 51          CORRENTINA            BA                  NaN     2012-02-05
# 52            LONDRINA            PR                 SBLO     2012-02-05
# 54           PALESTINA            SP                  NaN     2012-02-06
# 113           LONDRINA            PR                 SBLO     2012-03-10
# 172          ITIRAPINA            SP                  NaN     2012-04-13
# ...                ...           ...                  ...            ...
# 5040           VILHENA            RO                  NaN     2021-09-29
# 5045          TERESINA            PI                 SBTE     2021-10-08
# 5068           VILHENA            RO                  NaN     2021-10-24
# 5100          TERESINA            PI                 SBTE     2021-11-17
# 5166         PETROLINA            PE                 SBPL     2021-12-31
#
#      ocorrencia_hora  total_recomendacoes ocorrencia_dia_hora
# 51          20:27:00                    0 2012-02-05 20:27:00
# 52          17:34:00                    0 2012-02-05 17:34:00
# 54          19:30:00                    0 2012-02-06 19:30:00
# 113         16:35:00                    0 2012-03-10 16:35:00
# 172         15:45:00                    0 2012-04-13 15:45:00
# ...              ...                  ...                 ...
# 5040        15:10:00                    0 2021-09-29 15:10:00
# 5045        16:20:00                    0 2021-10-08 16:20:00
# 5068        18:40:00                    0 2021-10-24 18:40:00
# 5100        14:40:00                    0 2021-11-17 14:40:00
# 5166        20:30:00                    0 2021-12-31 20:30:00
#
# [237 rows x 10 columns]

# %%
#ocorrencias cuja cidade contém MA
filtro = df.ocorrencia_cidade.str.contains('MA')
df.loc[filtro]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 12                45396               45396          INCIDENTE GRAVE
# 16                45693               45693                INCIDENTE
# 45                45682               45682                INCIDENTE
# 59                45580               45580          INCIDENTE GRAVE
# 79                45715               45715                INCIDENTE
# ...                 ...                 ...                      ...
# 5138              80428               80428                 ACIDENTE
# 5153              80461               80461                INCIDENTE
# 5156              80463               80463                INCIDENTE
# 5160              80451               80451                INCIDENTE
# 5163              80452               80452                 ACIDENTE
#
#             ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo  \
# 12                     MARABÁ            PA                 SBMA
# 16                      MACAÉ            RJ                  NaN
# 45                      MACAÉ            RJ                  NaN
# 59                      MACAÉ            RJ                  NaN
# 79                     MANAUS            AM                 SWFN
# ...                       ...           ...                  ...
# 5138  SANTA VITÓRIA DO PALMAR            RS                  NaN
# 5153                  MARINGÁ            PR                 SBMG
# 5156                  MARINGÁ            PR                 SBMG
# 5160                   MANAUS            AM                 SBEG
# 5163                  MARACAÍ            SP                  NaN
#
#      ocorrencia_dia ocorrencia_hora  total_recomendacoes ocorrencia_dia_hora
# 12       2012-01-11        11:21:00                    0 2012-01-11 11:21:00
# 16       2012-01-14        10:30:00                    0 2012-01-14 10:30:00
# 45       2012-02-01        13:50:00                    0 2012-02-01 13:50:00
# 59       2012-02-07        14:50:00                    4 2012-02-07 14:50:00
# 79       2012-02-20        09:10:00                    0 2012-02-20 09:10:00
# ...             ...             ...                  ...                 ...
# 5138     2021-12-11        19:40:00                    0 2021-12-11 19:40:00
# 5153     2021-12-24        03:30:00                    0 2021-12-24 03:30:00
# 5156     2021-12-28        16:11:00                    0 2021-12-28 16:11:00
# 5160     2021-12-30        14:41:00                    0 2021-12-30 14:41:00
# 5163     2021-12-31        09:30:00                    0 2021-12-31 09:30:00
#
# [423 rows x 10 columns]

# %%
#ocorrencias cuja cidade contém MA ou AL
filtro = df.ocorrencia_cidade.str.contains('MA|AL')
df.loc[filtro]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 52242               52242                INCIDENTE
# 8                 45391               45391                 ACIDENTE
# 11                52245               52245                INCIDENTE
# 12                45396               45396          INCIDENTE GRAVE
# 16                45693               45693                INCIDENTE
# ...                 ...                 ...                      ...
# 5153              80461               80461                INCIDENTE
# 5154              80468               80468                INCIDENTE
# 5156              80463               80463                INCIDENTE
# 5160              80451               80451                INCIDENTE
# 5163              80452               80452                 ACIDENTE
#
#           ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0              PORTO ALEGRE            RS                 SBPA     2012-01-05
# 8     CONCEIÇÃO DAS ALAGOAS            MG                  NaN     2012-01-08
# 11             PORTO ALEGRE            RS                 SBPA     2012-01-09
# 12                   MARABÁ            PA                 SBMA     2012-01-11
# 16                    MACAÉ            RJ                  NaN     2012-01-14
# ...                     ...           ...                  ...            ...
# 5153                MARINGÁ            PR                 SBMG     2021-12-24
# 5154               SALVADOR            BA                 SBSV     2021-12-26
# 5156                MARINGÁ            PR                 SBMG     2021-12-28
# 5160                 MANAUS            AM                 SBEG     2021-12-30
# 5163                MARACAÍ            SP                  NaN     2021-12-31
#
#      ocorrencia_hora  total_recomendacoes ocorrencia_dia_hora
# 0           20:27:00                    0 2012-01-05 20:27:00
# 8           16:00:00                    0 2012-01-08 16:00:00
# 11          13:36:00                    0 2012-01-09 13:36:00
# 12          11:21:00                    0 2012-01-11 11:21:00
# 16          10:30:00                    0 2012-01-14 10:30:00
# ...              ...                  ...                 ...
# 5153        03:30:00                    0 2021-12-24 03:30:00
# 5154        16:56:00                    0 2021-12-26 16:56:00
# 5156        16:11:00                    0 2021-12-28 16:11:00
# 5160        14:41:00                    0 2021-12-30 14:41:00
# 5163        09:30:00                    0 2021-12-31 09:30:00
#
# [791 rows x 10 columns]

# %%
#ocorrencias do ano de 2015
filtro = df.ocorrencia_dia.dt.year == 2015
df.loc[filtro]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 1870              52992               52992          INCIDENTE GRAVE
# 1871              52979               52979                 ACIDENTE
# 1872              53073               53073                INCIDENTE
# 1873              53074               53074                INCIDENTE
# 1874              52976               52976                 ACIDENTE
# ...                 ...                 ...                      ...
# 2336              60632               60632          INCIDENTE GRAVE
# 2337              60600               60600                INCIDENTE
# 2338              60642               60642                INCIDENTE
# 2339              60631               60631                 ACIDENTE
# 2340              60649               60649                 ACIDENTE
#
#          ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 1870              SALVADOR            BA                 SBSV     2015-01-01
# 1871              IVINHEMA            MS                  NaN     2015-01-02
# 1872                  TEFÉ            AM                 SBTF     2015-01-02
# 1873        BELO HORIZONTE            MG                 SBBH     2015-01-02
# 1874                TOLEDO            PR                 SBTD     2015-01-04
# ...                    ...           ...                  ...            ...
# 2336               ITABERÁ            SP                  NaN     2015-12-24
# 2337             GUARULHOS            SP                 SBGR     2015-12-25
# 2338  SÃO FRANCISCO DO SUL            SC                 SSSS     2015-12-26
# 2339             MAÇAMBARÁ            RS                  NaN     2015-12-28
# 2340            PORTO BELO            SC                 SDEN     2015-12-31
#
#      ocorrencia_hora  total_recomendacoes ocorrencia_dia_hora
# 1870        11:40:00                    3 2015-01-01 11:40:00
# 1871        14:50:00                    0 2015-01-02 14:50:00
# 1872        16:28:00                    0 2015-01-02 16:28:00
# 1873        20:34:00                    0 2015-01-02 20:34:00
# 1874        22:04:00                    6 2015-01-04 22:04:00
# ...              ...                  ...                 ...
# 2336        14:00:00                    0 2015-12-24 14:00:00
# 2337        19:00:00                    0 2015-12-25 19:00:00
# 2338        16:00:00                    0 2015-12-26 16:00:00
# 2339        19:00:00                    2 2015-12-28 19:00:00
# 2340        14:00:00                    0 2015-12-31 14:00:00
#
# [471 rows x 10 columns]

# %%
#ocorrencias do ano de 2015 no mês de Dezembro
filtro1 = df.ocorrencia_dia.dt.year == 2015
filtro2 = df.ocorrencia_dia.dt.month == 12
df.loc[filtro1 & filtro2]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 2302              53573               53573                INCIDENTE
# 2303              60601               60601                INCIDENTE
# 2304              53634               53634                INCIDENTE
# 2305              53636               53636                INCIDENTE
# 2306              53575               53575                INCIDENTE
# 2307              60637               60637                INCIDENTE
# 2308              53625               53625                 ACIDENTE
# 2309              53626               53626                 ACIDENTE
# 2310              53628               53628                 ACIDENTE
# 2311              53629               53629          INCIDENTE GRAVE
# 2312              53631               53631                INCIDENTE
# 2313              60636               60636                INCIDENTE
# 2314              53627               53627                INCIDENTE
# 2315              60604               60604                INCIDENTE
# 2316              60611               60611                INCIDENTE
# 2317              60613               60613                 ACIDENTE
# 2318              60629               60629                 ACIDENTE
# 2319              53630               53630                INCIDENTE
# 2320              60603               60603                INCIDENTE
# 2321              60612               60612                 ACIDENTE
# 2322              60783               60783                 ACIDENTE
# 2323              53639               53639                INCIDENTE
# 2324              60609               60609          INCIDENTE GRAVE
# 2325              60616               60616                 ACIDENTE
# 2326              60620               60620                 ACIDENTE
# 2327              60645               60645                 ACIDENTE
# 2328              60608               60608                INCIDENTE
# 2329              60625               60625                 ACIDENTE
# 2330              60605               60605                INCIDENTE
# 2331              60610               60610                INCIDENTE
# 2332              60602               60602                INCIDENTE
# 2333              60615               60615                INCIDENTE
# 2334              60640               60640                INCIDENTE
# 2335              60641               60641                INCIDENTE
# 2336              60632               60632          INCIDENTE GRAVE
# 2337              60600               60600                INCIDENTE
# 2338              60642               60642                INCIDENTE
# 2339              60631               60631                 ACIDENTE
# 2340              60649               60649                 ACIDENTE
#
#           ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 2302              GUARULHOS            SP                 SBGR     2015-12-01
# 2303                 PALMAS            TO                 SBPJ     2015-12-01
# 2304                 PALMAS            TO                 SBPJ     2015-12-02
# 2305                JUNDIAÍ            SP                 SBJD     2015-12-02
# 2306  CAMPOS DOS GOYTACAZES            RJ                 SBFS     2015-12-03
# 2307         BELO HORIZONTE            MG                 SBBH     2015-12-03
# 2308               TRINDADE            GO                  NaN     2015-12-06
# 2309              AMERICANA            SP                 SDAI     2015-12-06
# 2310                  AGUAÍ            SP                  NaN     2015-12-08
# 2311                  JALES            SP                 SDJL     2015-12-08
# 2312               CAMPINAS            SP                 SBKP     2015-12-08
# 2313          CAXIAS DO SUL            RS                 SBCX     2015-12-08
# 2314               TERESINA            PI                 SBTE     2015-12-12
# 2315                GOIÂNIA            GO                 SBGO     2015-12-12
# 2316              SÃO PAULO            SP                 SBSP     2015-12-12
# 2317             JUSCIMEIRA            MT                 SWMO     2015-12-12
# 2318             RIO GRANDE            RS                  NaN     2015-12-12
# 2319                MARÍLIA            SP                 SBML     2015-12-13
# 2320               LONDRINA            PR                 SBLO     2015-12-13
# 2321        BENTO GONÇALVES            RS                 SSBG     2015-12-13
# 2322                  LAGES            SC                  NaN     2015-12-13
# 2323               LOUVEIRA            SP                 SDAM     2015-12-15
# 2324              ARAGUAÍNA            TO                 SWGN     2015-12-15
# 2325               PALOTINA            PR                  NaN     2015-12-15
# 2326         RIO DE JANEIRO            RJ                 SBJR     2015-12-15
# 2327            SERTÃOZINHO            SP                  NaN     2015-12-15
# 2328         BELO HORIZONTE            MG                 SBPR     2015-12-16
# 2329               ITÁPOLIS            SP                 SDIO     2015-12-17
# 2330             UBERLÂNDIA            MG                 SBUL     2015-12-18
# 2331                JUNDIAÍ            SP                 SBJD     2015-12-18
# 2332         RIBEIRÃO PRETO            SP                 SBRP     2015-12-22
# 2333              SÃO PAULO            SP                 SBMT     2015-12-22
# 2334               CASCAVEL            PR                 SBCA     2015-12-23
# 2335         BELO HORIZONTE            MG                 SBBH     2015-12-23
# 2336                ITABERÁ            SP                  NaN     2015-12-24
# 2337              GUARULHOS            SP                 SBGR     2015-12-25
# 2338   SÃO FRANCISCO DO SUL            SC                 SSSS     2015-12-26
# 2339              MAÇAMBARÁ            RS                  NaN     2015-12-28
# 2340             PORTO BELO            SC                 SDEN     2015-12-31
#
#      ocorrencia_hora  total_recomendacoes ocorrencia_dia_hora
# 2302        02:48:00                    0 2015-12-01 02:48:00
# 2303        16:05:00                    0 2015-12-01 16:05:00
# 2304        17:45:00                    0 2015-12-02 17:45:00
# 2305        17:42:00                    0 2015-12-02 17:42:00
# 2306        10:50:00                    0 2015-12-03 10:50:00
# 2307        16:47:00                    0 2015-12-03 16:47:00
# 2308        13:10:00                    3 2015-12-06 13:10:00
# 2309        15:00:00                    1 2015-12-06 15:00:00
# 2310        14:30:00                    1 2015-12-08 14:30:00
# 2311        10:20:00                    0 2015-12-08 10:20:00
# 2312        16:19:00                    0 2015-12-08 16:19:00
# 2313        13:00:00                    0 2015-12-08 13:00:00
# 2314        19:05:00                    0 2015-12-12 19:05:00
# 2315        14:34:00                    0 2015-12-12 14:34:00
# 2316        15:30:00                    0 2015-12-12 15:30:00
# 2317        08:31:00                    0 2015-12-12 08:31:00
# 2318        10:40:00                    0 2015-12-12 10:40:00
# 2319        13:50:00                    0 2015-12-13 13:50:00
# 2320        17:46:00                    0 2015-12-13 17:46:00
# 2321        20:30:00                    0 2015-12-13 20:30:00
# 2322        14:00:00                    3 2015-12-13 14:00:00
# 2323        14:20:00                    0 2015-12-15 14:20:00
# 2324        13:00:00                    0 2015-12-15 13:00:00
# 2325        20:30:00                    0 2015-12-15 20:30:00
# 2326        16:50:00                    4 2015-12-15 16:50:00
# 2327        13:00:00                    0 2015-12-15 13:00:00
# 2328        10:38:00                    0 2015-12-16 10:38:00
# 2329        21:30:00                    1 2015-12-17 21:30:00
# 2330        10:25:00                    0 2015-12-18 10:25:00
# 2331        18:45:00                    0 2015-12-18 18:45:00
# 2332        06:27:00                    0 2015-12-22 06:27:00
# 2333        13:07:00                    0 2015-12-22 13:07:00
# 2334        13:20:00                    0 2015-12-23 13:20:00
# 2335        15:53:00                    0 2015-12-23 15:53:00
# 2336        14:00:00                    0 2015-12-24 14:00:00
# 2337        19:00:00                    0 2015-12-25 19:00:00
# 2338        16:00:00                    0 2015-12-26 16:00:00
# 2339        19:00:00                    2 2015-12-28 19:00:00
# 2340        14:00:00                    0 2015-12-31 14:00:00

# %%
#ocorrencias do ano de 2015 no mês de Dezembro e dia 08
filtro1 = df.ocorrencia_dia.dt.year == 2015
filtro2 = df.ocorrencia_dia.dt.month == 12
filtro3 = df.ocorrencia_dia.dt.day == 8
df.loc[filtro1 & filtro2 & filtro3]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 2310              53628               53628                 ACIDENTE
# 2311              53629               53629          INCIDENTE GRAVE
# 2312              53631               53631                INCIDENTE
# 2313              60636               60636                INCIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 2310             AGUAÍ            SP                  NaN     2015-12-08
# 2311             JALES            SP                 SDJL     2015-12-08
# 2312          CAMPINAS            SP                 SBKP     2015-12-08
# 2313     CAXIAS DO SUL            RS                 SBCX     2015-12-08
#
#      ocorrencia_hora  total_recomendacoes ocorrencia_dia_hora
# 2310        14:30:00                    1 2015-12-08 14:30:00
# 2311        10:20:00                    0 2015-12-08 10:20:00
# 2312        16:19:00                    0 2015-12-08 16:19:00
# 2313        13:00:00                    0 2015-12-08 13:00:00

# %%
#ocorrencias do ano de 2015 no mês de Dezembro entre os dias 3 e 8
filtro1 = df.ocorrencia_dia.dt.year == 2015
filtro2 = df.ocorrencia_dia.dt.month == 12
filtro3 = (df.ocorrencia_dia.dt.day >= 3) & (df.ocorrencia_dia.dt.day <= 8)
df.loc[filtro1 & filtro2 & filtro3]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 2306              53575               53575                INCIDENTE
# 2307              60637               60637                INCIDENTE
# 2308              53625               53625                 ACIDENTE
# 2309              53626               53626                 ACIDENTE
# 2310              53628               53628                 ACIDENTE
# 2311              53629               53629          INCIDENTE GRAVE
# 2312              53631               53631                INCIDENTE
# 2313              60636               60636                INCIDENTE
#
#           ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 2306  CAMPOS DOS GOYTACAZES            RJ                 SBFS     2015-12-03
# 2307         BELO HORIZONTE            MG                 SBBH     2015-12-03
# 2308               TRINDADE            GO                  NaN     2015-12-06
# 2309              AMERICANA            SP                 SDAI     2015-12-06
# 2310                  AGUAÍ            SP                  NaN     2015-12-08
# 2311                  JALES            SP                 SDJL     2015-12-08
# 2312               CAMPINAS            SP                 SBKP     2015-12-08
# 2313          CAXIAS DO SUL            RS                 SBCX     2015-12-08
#
#      ocorrencia_hora  total_recomendacoes ocorrencia_dia_hora
# 2306        10:50:00                    0 2015-12-03 10:50:00
# 2307        16:47:00                    0 2015-12-03 16:47:00
# 2308        13:10:00                    3 2015-12-06 13:10:00
# 2309        15:00:00                    1 2015-12-06 15:00:00
# 2310        14:30:00                    1 2015-12-08 14:30:00
# 2311        10:20:00                    0 2015-12-08 10:20:00
# 2312        16:19:00                    0 2015-12-08 16:19:00
# 2313        13:00:00                    0 2015-12-08 13:00:00

# %% [markdown]
# **Sugestão do professor:** Podem ser criadas novas colunas a fim de facilitar a extração de dados na obtenção de novas informações. Segue exemplo abaixo no qual se deseja operar sobre o horário das ocorrências.

# %%
#cria nova coluna ao cocatenar informações de duas colunas como string e depois converter o resultado como datetime
df['ocorrencia_dia_hora'] = pd.to_datetime(df.ocorrencia_dia.astype(str) + ' ' + df.ocorrencia_hora)

# %%
filtro_1 = df.ocorrencia_dia_hora >= '2015-12-03 11:00:00'
filtro_2 = df.ocorrencia_dia_hora <= '2015-12-08 23:00:00'
df.loc[filtro_1 & filtro_2]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 2307              60637               60637                INCIDENTE
# 2308              53625               53625                 ACIDENTE
# 2309              53626               53626                 ACIDENTE
# 2310              53628               53628                 ACIDENTE
# 2311              53629               53629          INCIDENTE GRAVE
# 2312              53631               53631                INCIDENTE
# 2313              60636               60636                INCIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 2307    BELO HORIZONTE            MG                 SBBH     2015-12-03
# 2308          TRINDADE            GO                  NaN     2015-12-06
# 2309         AMERICANA            SP                 SDAI     2015-12-06
# 2310             AGUAÍ            SP                  NaN     2015-12-08
# 2311             JALES            SP                 SDJL     2015-12-08
# 2312          CAMPINAS            SP                 SBKP     2015-12-08
# 2313     CAXIAS DO SUL            RS                 SBCX     2015-12-08
#
#      ocorrencia_hora  total_recomendacoes ocorrencia_dia_hora
# 2307        16:47:00                    0 2015-12-03 16:47:00
# 2308        13:10:00                    3 2015-12-06 13:10:00
# 2309        15:00:00                    1 2015-12-06 15:00:00
# 2310        14:30:00                    1 2015-12-08 14:30:00
# 2311        10:20:00                    0 2015-12-08 10:20:00
# 2312        16:19:00                    0 2015-12-08 16:19:00
# 2313        13:00:00                    0 2015-12-08 13:00:00

# %% [markdown]
# <h5> Agrupamento de dados </h5>

# %% [markdown]
# O agrupamento de dados pode ser usado para obter novos conjunto de dados.

# %%
#Ocorrencias do ano de 2015 e mês de Março
filtro1 = df.ocorrencia_dia.dt.year == 2015
filtro2 = df.ocorrencia_dia.dt.month == 3
df201503 = df.loc[filtro1 & filtro2] #Novo dataframe
df201503
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 1960              53183               53183                 ACIDENTE
# 1961              53120               53120                 ACIDENTE
# 1962              53109               53109                 ACIDENTE
# 1963              53112               53112                 ACIDENTE
# 1964              53152               53152          INCIDENTE GRAVE
# 1965              53167               53167                INCIDENTE
# 1966              53596               53596                INCIDENTE
# 1967              53149               53149                 ACIDENTE
# 1968              53148               53148                 ACIDENTE
# 1969              53153               53153                INCIDENTE
# 1970              53154               53154                INCIDENTE
# 1971              53238               53238                INCIDENTE
# 1972              53189               53189                INCIDENTE
# 1973              53193               53193                 ACIDENTE
# 1974              53164               53164                 ACIDENTE
# 1975              53151               53151          INCIDENTE GRAVE
# 1976              53168               53168                INCIDENTE
# 1977              53169               53169                INCIDENTE
# 1978              53165               53165          INCIDENTE GRAVE
# 1979              53188               53188                INCIDENTE
# 1980              53184               53184                 ACIDENTE
# 1981              53178               53178                 ACIDENTE
# 1982              53182               53182                 ACIDENTE
# 1983              53166               53166          INCIDENTE GRAVE
# 1984              53170               53170                INCIDENTE
# 1985              53185               53185                INCIDENTE
# 1986              53412               53412          INCIDENTE GRAVE
# 1987              53194               53194                 ACIDENTE
# 1988              53186               53186                INCIDENTE
# 1989              53179               53179                 ACIDENTE
# 1990              53180               53180                 ACIDENTE
# 1991              53190               53190                INCIDENTE
# 1992              53212               53212                INCIDENTE
# 1993              53213               53213                INCIDENTE
# 1994              53181               53181                 ACIDENTE
# 1995              53187               53187                INCIDENTE
# 1996              53211               53211                INCIDENTE
#
#         ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 1960              AMAPORÃ            PR                  NaN     2015-03-02
# 1961               CHAVES            PA                 SNXW     2015-03-04
# 1962         CAMPO GRANDE            MS                 SSIE     2015-03-05
# 1963           MOGI GUAÇU            SP                  NaN     2015-03-06
# 1964       RIO DE JANEIRO            RJ                 SBRJ     2015-03-10
# 1965               MARABÁ            PA                 SBMA     2015-03-10
# 1966              ITAPEMA            SC                  NaN     2015-03-10
# 1967            TABATINGA            AM                 SBTT     2015-03-11
# 1968               ARARAS            SP                 SDEH     2015-03-12
# 1969         PORTO ALEGRE            RS                 SBPA     2015-03-13
# 1970             SOROCABA            SP                 SDCO     2015-03-13
# 1971                SERRA            ES                  NaN     2015-03-13
# 1972              CONFINS            MG                 SBCF     2015-03-14
# 1973             CANARANA            MT                  NaN     2015-03-14
# 1974      PRINCESA ISABEL            PB                  NaN     2015-03-15
# 1975                MAUÉS            AM                 SWMW     2015-03-16
# 1976        PARÁ DE MINAS            MG                 SNPA     2015-03-16
# 1977                BELÉM            PA                 SBBE     2015-03-19
# 1978        SÃO DESIDÉRIO            BA                  NaN     2015-03-20
# 1979       RIO DE JANEIRO            RJ                 SBJR     2015-03-20
# 1980          PORTO UNIÃO            SC                  NaN     2015-03-22
# 1981           DIAMANTINO            MT                  NaN     2015-03-23
# 1982          SANTA LUZIA            MA                  NaN     2015-03-23
# 1983    RIACHÃO DAS NEVES            BA                  NaN     2015-03-24
# 1984              CONFINS            MG                 SBCF     2015-03-24
# 1985             CURITIBA            PR                 SBCT     2015-03-24
# 1986                MACAÉ            RJ                  NaN     2015-03-24
# 1987  GUARACIABA DO NORTE            CE                 SWBE     2015-03-26
# 1988             BRASÍLIA            DF                  NaN     2015-03-27
# 1989            CAIAPÔNIA            GO                  NaN     2015-03-28
# 1990             ARAGUARI            MG                  NaN     2015-03-28
# 1991             CAMPINAS            SP                 SBKP     2015-03-28
# 1992              JUNDIAÍ            SP                 SBJD     2015-03-28
# 1993              JUNDIAÍ            SP                 SBJD     2015-03-28
# 1994              COLÍDER            MT                  NaN     2015-03-29
# 1995            JOINVILLE            SC                 SBJV     2015-03-29
# 1996                BAURU            SP                 SBBU     2015-03-30
#
#      ocorrencia_hora  total_recomendacoes ocorrencia_dia_hora
# 1960        23:00:00                    0 2015-03-02 23:00:00
# 1961        13:30:00                    0 2015-03-04 13:30:00
# 1962        13:50:00                    0 2015-03-05 13:50:00
# 1963        21:00:00                    1 2015-03-06 21:00:00
# 1964        11:30:00                    2 2015-03-10 11:30:00
# 1965        17:33:00                    0 2015-03-10 17:33:00
# 1966        21:35:00                    0 2015-03-10 21:35:00
# 1967        23:25:00                    0 2015-03-11 23:25:00
# 1968        12:40:00                    0 2015-03-12 12:40:00
# 1969        15:45:00                    0 2015-03-13 15:45:00
# 1970        14:40:00                    0 2015-03-13 14:40:00
# 1971        11:30:00                    0 2015-03-13 11:30:00
# 1972        07:20:00                    0 2015-03-14 07:20:00
# 1973        18:00:00                    0 2015-03-14 18:00:00
# 1974        18:30:00                    0 2015-03-15 18:30:00
# 1975        18:07:00                    1 2015-03-16 18:07:00
# 1976        21:05:00                    0 2015-03-16 21:05:00
# 1977        03:25:00                    0 2015-03-19 03:25:00
# 1978        14:35:00                    0 2015-03-20 14:35:00
# 1979        21:00:00                    0 2015-03-20 21:00:00
# 1980        13:44:00                    0 2015-03-22 13:44:00
# 1981        17:15:00                    0 2015-03-23 17:15:00
# 1982        20:40:00                    0 2015-03-23 20:40:00
# 1983        14:45:00                    0 2015-03-24 14:45:00
# 1984        17:57:00                    0 2015-03-24 17:57:00
# 1985        23:01:00                    0 2015-03-24 23:01:00
# 1986        16:35:00                    0 2015-03-24 16:35:00
# 1987        20:30:00                    0 2015-03-26 20:30:00
# 1988        14:55:00                    0 2015-03-27 14:55:00
# 1989        10:30:00                    0 2015-03-28 10:30:00
# 1990        18:52:00                    0 2015-03-28 18:52:00
# 1991        16:26:00                    0 2015-03-28 16:26:00
# 1992        17:32:00                    0 2015-03-28 17:32:00
# 1993        15:51:00                    0 2015-03-28 15:51:00
# 1994        20:17:00                    0 2015-03-29 20:17:00
# 1995        18:36:00                    0 2015-03-29 18:36:00
# 1996        19:40:00                    0 2015-03-30 19:40:00

# %%
#Conta o número de valores disponíveis por coluna.
df201503.count()
# Out:
# codigo_ocorrencia           37
# codigo_ocorrencia2          37
# ocorrencia_classificacao    37
# ocorrencia_cidade           37
# ocorrencia_uf               37
# ocorrencia_aerodromo        21
# ocorrencia_dia              37
# ocorrencia_hora             37
# total_recomendacoes         37
# ocorrencia_dia_hora         37
# dtype: int64

# %% [markdown]
# No exemplo abaixo obtemos o número de ocorrências para cada classificação que ocorreu em Março de 2015

# %%
df201503.groupby(['ocorrencia_classificacao']).ocorrencia_classificacao.count()
# Out:
# ocorrencia_classificacao
# ACIDENTE           15
# INCIDENTE          17
# INCIDENTE GRAVE     5
# Name: ocorrencia_classificacao, dtype: int64

# %% [markdown]
# No exemplo abaixo, observamos que em Março de 2015 ocorreram 5 acidentes em aeródromos, ocorreram 14 incidentes em aeródromos e ocorreram 2 incidentes graves em aeródromos. Logo se pode concluir que 21 ocorrências foram em aeródromos e, pelo resultado obtido anteriormente, 16 ocorrências não foram em aeródromos (diferença em *missing values*). O comando abaixo agrupa pela coluna ocorrencia_classificacao e conta apenas valores disponíveis para a coluna ocorrencia_aerodromo, logo não é adequado para contar por classificação de ocorrência.

# %%
df201503.groupby(['ocorrencia_classificacao']).ocorrencia_aerodromo.count()
# Out:
# ocorrencia_classificacao
# ACIDENTE            5
# INCIDENTE          14
# INCIDENTE GRAVE     2
# Name: ocorrencia_aerodromo, dtype: int64

# %% [markdown]
# A função ***size()*** conta o número de linhas por agrupamento e é uma alternativa à função ***count()***.

# %%
df201503.groupby(['ocorrencia_classificacao']).size()
# Out:
# ocorrencia_classificacao
# ACIDENTE           15
# INCIDENTE          17
# INCIDENTE GRAVE     5
# dtype: int64

# %%
#Ordena os resultados
df201503.groupby(['ocorrencia_classificacao']).size().sort_values()
# Out:
# ocorrencia_classificacao
# INCIDENTE GRAVE     5
# ACIDENTE           15
# INCIDENTE          17
# dtype: int64

# %%
#Ocorrencias na região Sudeste em 2015
filtro1 = df.ocorrencia_dia.dt.year == 2015
filtro2 = df.ocorrencia_uf.isin(['SP','MG','RJ','ES'])
dfsudeste2015 = df.loc[filtro1 & filtro2]
dfsudeste2015
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 1873              53074               53074                INCIDENTE
# 1875              53075               53075                INCIDENTE
# 1876              53076               53076                INCIDENTE
# 1879              53072               53072                INCIDENTE
# 1880              52994               52994                INCIDENTE
# ...                 ...                 ...                      ...
# 2332              60602               60602                INCIDENTE
# 2333              60615               60615                INCIDENTE
# 2335              60641               60641                INCIDENTE
# 2336              60632               60632          INCIDENTE GRAVE
# 2337              60600               60600                INCIDENTE
#
#       ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 1873     BELO HORIZONTE            MG                 SBBH     2015-01-02
# 1875            JUNDIAÍ            SP                 SBJD     2015-01-05
# 1876  BRAGANÇA PAULISTA            SP                  NaN     2015-01-06
# 1879     BELO HORIZONTE            MG                 SBBH     2015-01-08
# 1880          SÃO PAULO            SP                 SBMT     2015-01-09
# ...                 ...           ...                  ...            ...
# 2332     RIBEIRÃO PRETO            SP                 SBRP     2015-12-22
# 2333          SÃO PAULO            SP                 SBMT     2015-12-22
# 2335     BELO HORIZONTE            MG                 SBBH     2015-12-23
# 2336            ITABERÁ            SP                  NaN     2015-12-24
# 2337          GUARULHOS            SP                 SBGR     2015-12-25
#
#      ocorrencia_hora  total_recomendacoes ocorrencia_dia_hora
# 1873        20:34:00                    0 2015-01-02 20:34:00
# 1875        10:19:00                    0 2015-01-05 10:19:00
# 1876        11:30:00                    0 2015-01-06 11:30:00
# 1879        21:13:00                    0 2015-01-08 21:13:00
# 1880        23:25:00                    0 2015-01-09 23:25:00
# ...              ...                  ...                 ...
# 2332        06:27:00                    0 2015-12-22 06:27:00
# 2333        13:07:00                    0 2015-12-22 13:07:00
# 2335        15:53:00                    0 2015-12-23 15:53:00
# 2336        14:00:00                    0 2015-12-24 14:00:00
# 2337        19:00:00                    0 2015-12-25 19:00:00
#
# [207 rows x 10 columns]

# %%
#Exibe o número de ocorrências por classificação que ocorreram em 2015 na regiao Sudeste
dfsudeste2015.groupby(['ocorrencia_classificacao']).size()
# Out:
# ocorrencia_classificacao
# ACIDENTE            60
# INCIDENTE          128
# INCIDENTE GRAVE     19
# dtype: int64

# %%
dfsudeste2015.count()
# Out:
# codigo_ocorrencia           207
# codigo_ocorrencia2          207
# ocorrencia_classificacao    207
# ocorrencia_cidade           207
# ocorrencia_uf               207
# ocorrencia_aerodromo        152
# ocorrencia_dia              207
# ocorrencia_hora             207
# total_recomendacoes         207
# ocorrencia_dia_hora         207
# dtype: int64

# %%
#Exibe o numero de ocorrências por classificação em cada estado
dfsudeste2015.groupby(['ocorrencia_classificacao','ocorrencia_uf']).size()
# Out:
# ocorrencia_classificacao  ocorrencia_uf
# ACIDENTE                  ES                1
#                           MG               18
#                           RJ                6
#                           SP               35
# INCIDENTE                 ES                2
#                           MG               31
#                           RJ               17
#                           SP               78
# INCIDENTE GRAVE           ES                1
#                           MG                2
#                           RJ                7
#                           SP                9
# dtype: int64

# %%
#Exibe cada estado e suas ocorrencias por classificacao
dfsudeste2015.groupby(['ocorrencia_uf','ocorrencia_classificacao']).size()
# Out:
# ocorrencia_uf  ocorrencia_classificacao
# ES             ACIDENTE                     1
#                INCIDENTE                    2
#                INCIDENTE GRAVE              1
# MG             ACIDENTE                    18
#                INCIDENTE                   31
#                INCIDENTE GRAVE              2
# RJ             ACIDENTE                     6
#                INCIDENTE                   17
#                INCIDENTE GRAVE              7
# SP             ACIDENTE                    35
#                INCIDENTE                   78
#                INCIDENTE GRAVE              9
# dtype: int64

# %%
#Exibe o número de ocorrencias por cidade do Sudeste no ano de 2015
dfsudeste2015.groupby(['ocorrencia_cidade']).size().sort_values(ascending=False)
# Out:
# ocorrencia_cidade
# SÃO PAULO          25
# RIO DE JANEIRO     19
# BELO HORIZONTE     18
# JUNDIAÍ            14
# GUARULHOS          10
#                    ..
# ITARIRI             1
# ITAPIRA             1
# ITABERÁ             1
# IBATÉ               1
# ÁLVARES MACHADO     1
# Length: 86, dtype: int64

# %%
filtro1 = dfsudeste2015.ocorrencia_cidade == 'RIO DE JANEIRO'
filtro2 = dfsudeste2015.total_recomendacoes > 0
dfsudeste2015.loc[filtro1 & filtro2]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 1964              53152               53152          INCIDENTE GRAVE
# 2326              60620               60620                 ACIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 1964    RIO DE JANEIRO            RJ                 SBRJ     2015-03-10
# 2326    RIO DE JANEIRO            RJ                 SBJR     2015-12-15
#
#      ocorrencia_hora  total_recomendacoes ocorrencia_dia_hora
# 1964        11:30:00                    2 2015-03-10 11:30:00
# 2326        16:50:00                    4 2015-12-15 16:50:00

# %%
#Imprime total de recomendacoes do Rio de Janeiro em 2015
filtro = dfsudeste2015.ocorrencia_cidade == 'RIO DE JANEIRO'
dfsudeste2015.loc[filtro].total_recomendacoes.sum()
# Out:
# 6

# %%
#CD - Número de recomendaçoes por cidade
dfsudeste2015.groupby(['ocorrencia_cidade']).total_recomendacoes.sum().sort_values(ascending=False)
# Out:
# ocorrencia_cidade
# RIO DE JANEIRO     6
# CARAPICUÍBA        5
# BELO HORIZONTE     4
# PIRACICABA         2
# OURO PRETO         2
#                   ..
# IBATÉ              0
# GUARULHOS          0
# GUARDA-MOR         0
# GUARAPARI          0
# ÁLVARES MACHADO    0
# Name: total_recomendacoes, Length: 86, dtype: int64

# %% [markdown]
# Para levar em consideração valores insdisponíveis em agrupamentos, o parâmetro ***dropna=False*** deve ser usado. Segue exemplo abaixo:

# %%
#CD - Número de recomendaçoes por aeródromo. Observe que valor indisponível é considerado 
dfsudeste2015.groupby(['ocorrencia_aerodromo'], dropna=False).total_recomendacoes.sum().sort_values(ascending=False)
# Out:
# ocorrencia_aerodromo
# NaN     16
# SBJR     4
# SBPR     4
# SDPW     2
# SBRJ     2
# SBME     2
# SNVC     1
# SDIO     1
# SDET     1
# SBBP     1
# SDAI     1
# SBGW     1
# SBJD     0
# SIBH     0
# SDJL     0
# SDJO     0
# SDMH     0
# SBCB     0
# SDRK     0
# SDTF     0
# SDVE     0
# SDVH     0
# SIVU     0
# SBCF     0
# SJLY     0
# SNBR     0
# SNDV     0
# SNHB     0
# SNKF     0
# SNPA     0
# SBBU     0
# SSOL     0
# SDJC     0
# SBFS     0
# SBKP     0
# SDEM     0
# SBML     0
# SBMT     0
# SBPC     0
# SBGV     0
# SBGR     0
# SBRP     0
# SBSJ     0
# SBSP     0
# SBSR     0
# SBST     0
# SBUL     0
# SBUR     0
# SBVT     0
# SBGL     0
# SDAM     0
# SDCO     0
# SDEH     0
# SBBH     0
# Name: total_recomendacoes, dtype: int64

# %%
#Exibe o número total de recomendacoes, desde que sejam maiores que zero, por cidade.
filtro = df.total_recomendacoes > 0
dfsudeste2015.loc[filtro].groupby(['ocorrencia_cidade']).total_recomendacoes.sum().sort_values(ascending=False)
# Out:
# ocorrencia_cidade
# RIO DE JANEIRO       6
# CARAPICUÍBA          5
# BELO HORIZONTE       4
# MACAÉ                2
# PIRACICABA           2
# OURO PRETO           2
# ITARIRI              2
# AGUAÍ                1
# TIETÊ                1
# MOGI GUAÇU           1
# MIRACATU             1
# ITÁPOLIS             1
# JUNDIAÍ              1
# AMERICANA            1
# ITAPIRA              1
# GUARATINGUETÁ        1
# CATANDUVA            1
# CABECEIRA GRANDE     1
# BRAGANÇA PAULISTA    1
# VIÇOSA               1
# Name: total_recomendacoes, dtype: int64

# %%
#Exibe o número total de recomendacoes, desde que sejam maiores que zero, por cidade e mês
filtro = df.total_recomendacoes > 0
dfsudeste2015.loc[filtro].groupby(['ocorrencia_cidade', dfsudeste2015.ocorrencia_dia.dt.month]).total_recomendacoes.sum()
# Out:
# ocorrencia_cidade  ocorrencia_dia
# AGUAÍ              12                1
# AMERICANA          12                1
# BELO HORIZONTE     8                 4
# BRAGANÇA PAULISTA  11                1
# CABECEIRA GRANDE   5                 1
# CARAPICUÍBA        4                 5
# CATANDUVA          4                 1
# GUARATINGUETÁ      6                 1
# ITAPIRA            2                 1
# ITARIRI            8                 2
# ITÁPOLIS           12                1
# JUNDIAÍ            11                1
# MACAÉ              6                 2
# MIRACATU           11                1
# MOGI GUAÇU         3                 1
# OURO PRETO         6                 2
# PIRACICABA         6                 2
# RIO DE JANEIRO     3                 2
#                    12                4
# TIETÊ              5                 1
# VIÇOSA             5                 1
# Name: total_recomendacoes, dtype: int64

# %%
#localizamos as linhas com os filtros correspondentes para uma verificacao do resultado acima
filtro1 = df.total_recomendacoes > 0
filtro2 = df.ocorrencia_cidade == 'RIO DE JANEIRO'
dfsudeste2015.loc[filtro1 & filtro2]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 1964              53152               53152          INCIDENTE GRAVE
# 2326              60620               60620                 ACIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 1964    RIO DE JANEIRO            RJ                 SBRJ     2015-03-10
# 2326    RIO DE JANEIRO            RJ                 SBJR     2015-12-15
#
#      ocorrencia_hora  total_recomendacoes ocorrencia_dia_hora
# 1964        11:30:00                    2 2015-03-10 11:30:00
# 2326        16:50:00                    4 2015-12-15 16:50:00
